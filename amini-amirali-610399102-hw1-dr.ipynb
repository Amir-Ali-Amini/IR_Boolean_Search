# %% [markdown]
# # Developing an Information Retrieval System with Advanced Boolean Search
#
# ## AmirAli Amini - 610399102
#
# #### HW1

# %% [markdown]
# # توضیحات مسئله و چالش ها و بهبود ها
#
# بزرگ ترین چالش مسئله ساختار پستینگ لیست که برای سیو کردن مقادیر استفاده میشود بود چرا که باید به صورتی ذخیره شوند که برای هر داکیومنت علاوه بر شامل بود کلمه ، ایندکس های آن کلمه هم ذخیره شود.
#
# در این مسئله از ساختاری سریع تر از لینک لیست برای دسترسی به دیتا استفاده کردم
#
# همچنین از باینری سرچ برای بهبود سرعت پیدا کردن دیتا استفاده میکنم
#
# میتوان تمام دیکشنری های استفاده شده را با ارایه دو بعدی جایگذین کرد که تاثیری در سرعت کد زده شده ندارد و تنها خوانایی کد پایین اورده میشود

# %% [markdown]
# ## کتابخانه ها
#
# ###  from nltk import word_tokenize :
# از این کتابخانه برای تکنایز کردن داده ها به این دلیل که توکنایز کردن دیتا سریع تر میشه استفاده کردم
#
# ###  from nltk.corpus import stopwords :
# از این کتابخانه برای دریافت استاپینگ ورد های زبان انگلیسی استفاده کردم
#
# ###  import string:
# از این کتابخانه برای دریافت پانچویشن های زبان انگلیسی استفاده کردم
#
# ###  import numpy as np:
# از این کتابخانه برای جمع یک عدد با تمام اعضای یک آرایه استفاده کردم
#
# ###  import copy:
# از این کتابخانه برای دیپ کپی کردن ارایه استفاده کردم

# %%
from nltk.tokenize import word_tokenize


from nltk.corpus import stopwords # a library to tokenize input texts

import nltk


nltk.download('punkt')
nltk.download('stopwords') # stopping word in English language

import string # using to remove punctuation

import numpy as np

import copy
# Out:
# [nltk_data] Downloading package punkt to /Users/amirali/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/amirali/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Code
# برای رسیدن به هدف سوال، یک
# "posring list"
# با ساختار
# list of {word : nameOfWord , docs :[list of {doc:nameOfDocument , indexes: indexes of the word if this document}]}
# میسازم که هر خانه متناظر با یک کلمه است و ساختاری به صورت گفته شده دارد
#
# در این ساختار داکیومنت هایی که دارای این کلمه هستند در این قسمت ذخیره میشووند به این صورت که ایندکس هایی که برابر آن کلمه در آن داکیومنت هستند نگهداری میشود
#
# دلیل نگه داری اندکس کلمات در داکیومنت ها این است که در آینده بتوان با متد
#
# near
#
# اختلاف مکانی دو کلمه را پیدا کرد
#
#
# کلیت ساخت پستینگ لیست به این صورت است که کلمات هر داکیومنت را نگاه میکند در پستینگ لیست پس از پیدا کردن کلمه مورد نظر، مقدار ایندکس آن در داکیومنت حاضر و شماره داکیومنت ثبت میشود
#
# توضیحات جزئی تر در کد به صورت کامنت نوشته شده است
#
#
# ### input:
# تابع اینپوت ادرس داکیومنت ها را ورودی میگیرد و برای هر داکیومنت عملیات اضافه کردن به پستینگ لیست را انجام میدهد
#
# ### findWord:
# این تابع ایندکس متناظر با کلمه سرج شده را خروجی میدهد
#
# ### find:
# این در مرحله اول کویری داده شده را تجزیه میکند به ۳ کتگوری اصلی تقسیم بندی میشود
#
# - تک کلمه
# - بولین
# - همسایگی
#
# #### single word:
# برای تک کلمه به صورت مستثیم از تابع فایند ورد استفاده میکنم و ایندکس داکیومنت های آن را برمیگردانم
#
# #### boolean:
# برای بولین ها داکیومنت های هر کلمه را به همانند تک کلمه پیدا میکنم
#
# ##### AND:
# اشتراک لیست های بدست آمده را برمیگردانم
#
# ##### OR:
# اجتماع لیست های بدست آمده را برمیگردانم
#
#
# ### NEAR:
# برای کلمه اول و دوم برای هرکدام یک دیکشنری از داکیومنت های دارای آن کلمه میسازم که کلید آن اندکس داکیومنت و مقدار آن ایندکس کلمه در آن داکیومنت است
#
# برای هر دوداکیومنت مشترک در در دو کلمه ماتریس قدرمطلق فاصله متناظر با عضو های هردو را میسازم و مینیمم فاصله را بدست می آورم
#
# اگر کوچک تر از عدد خواسته شده بود آن داکیومنت را به جواب اضافه میکنم

# %% [markdown]
# # input 1 , text2.txt :
# aa aa  aa bb bb bb zz zz ll mm mm  aa aa ll
#
#
# amir ali amini amir hossein hasani
#
#
# # input 2 , test.tst:
# amirali , amini, hastam salam. amirali , amirali aa bb

# %%
class searchEngine:
    def __init__(self) -> None: # constructor of class
        self.postingList =[]
        self.files=[] 
        self.stop = set(stopwords.words('english') + list(string.punctuation)) # all extra expression which should ignore

        # structure of postingList : list of {word : nameOfWord , docs :[list of {doc:nameOfDocument , indexes: indexes of the word if this document}]}


    # binary search to find a word in posting list
    def searchPostingList(self, word):
        s= 0 
        e = len(self.postingList)
        if e <=0 :
            return 0
        e-=1
        while (1):
            if (e-s < 2):
                if (self.postingList[e]["word"] < word):
                    return e+1
                if (self.postingList[e]["word"] == word):
                    return e
                if (self.postingList[s]["word"] >= word):
                    return s

                return e
            mid = (s+e)/2
            mid = int(mid)
            if (word<self.postingList[mid]["word"]):
                e=mid
            elif (word> self.postingList[mid]["word"]):
                s = mid
            else :
                return mid
            
        # {word:str, indexes:list(int)}
    # binary search to find a word in each dictionary
    def searchDictionary(self, word,ls):
        s= 0 
        e = len(ls)
        if e <=0 :
            return 0
        e-=1
        while (1):
            if (e-s < 2):
                if (ls[e]["doc"] < word):
                    return e+1
                if (ls[e]["doc"] == word):
                    return e
                if (ls[s]["doc"] >= word):
                    return s

                return e
            mid = (s+e)/2
            mid = int(mid)
            if (word<ls[mid]["doc"]):
                e=mid
            elif (word> ls[mid]["doc"]):
                s = mid
            else :
                return mid


            
        # {doc:number, indexes:list(int)}



    def addToPostingList(self, tokenizedText: list[str],docIndex:int): # add tokenized word in posting list 
        for i in range(len(tokenizedText)):
            word = tokenizedText[i]
            index = self.searchPostingList(word) # find index of word in posting list
            if (len(self.postingList)>index): # check if index is not larger than posting list (if word is bigger that all words, search function returns len(postingList)+1)
                if (self.postingList[index]["word"] == word): # check if index is the index of the word
                    if (self.postingList[index]["docs"][-1]["doc"] == docIndex): # if we have already added the document index 
                        self.postingList[index]["docs"][-1]["indexes"].append(i) # as we read tokens in order of their index, we need to add token in end of the list

                    else:
                        self.postingList[index]["docs"].append({"doc":docIndex,"indexes":[i] }) # if we have not already added the document and dou to the fact that they are read in order of their index, we can easily add append new one in end of the list 

                else :
                    self.postingList[index:index]= [({"word":word , "docs":[{"doc":docIndex , "indexes":[i]}]})] # word is bigger that all other words => we can append it to end of the list

            else :
                self.postingList.append({"word":word , "docs":[{"doc":docIndex , "indexes":[i]}]}) # we have not already added the word and dou to the fact that they are read in order of their index, we can easily add append new one in end of the list


    def input (self, filePath: list[str]): # input paths of inputs
        for i in range(len(filePath)): # for files in input
            file = open(filePath[i],'r',encoding='cp1252') # open the file
            text = file.read() # read the file
            file.close()  # close the file
            # tokenize text and ignore stopping words using nltk library 
            tokenizedText = [word for word in word_tokenize(text.lower(),preserve_line=False) if word not in self.stop] 
            print (f'document {i+1} : {filePath[i]}')
            # print(tokenizedText)
            self.addToPostingList(tokenizedText , i+1) # i indicates to index of document we are reading


    def findWord(self, word): # this function use our binary search function to find word in posting list and if the word is not included in the list, returns -1
        index = self.searchPostingList(word)
        if (index< len(self.postingList)):
            if (self.postingList[index]["word"] == word):
                return index # real index of the word
        return -1 # word is not in the posting list


    def find(self , query:str): # split the query and find the result 
        splitQuery = query.lower().split()
        if (len(splitQuery)==1): # query is only one word
            index = self.findWord(splitQuery[0])
            if (index>-1):
                return [ i["doc"] for i in self.postingList[index]["docs"]]
            return []

        else: 
            index1 = self.findWord(splitQuery[0])
            index2 = self.findWord(splitQuery[2])
            if splitQuery[1] in ["and" ,"or", "AND", "OR"]: # boolean condition
                
                if (splitQuery[1] in ["and","AND"]): # and condition
                    if(index1!=-1 and index2!=-1): # check if there are result for both of words
                        docs1 =  set([ i["doc"] for i in self.postingList[index1]["docs"]]) # find document of word one 
                        docs2 =  set([ i["doc"] for i in self.postingList[index2]["docs"]]) # find document of word two 
                        # print(self.postingList[index1]["docs"] , self.postingList[index2]["docs"])
                        return list(docs1.intersection(docs2)) # make intersection of two results
                    return []
                    
                if (splitQuery[1] in ["or","OR"]): # or condition
                    if(index1!=-1 and index2!=-1): # check if there are result for both of words
                        docs1 =  set([ i["doc"] for i in self.postingList[index1]["docs"]])
                        docs2 =  set([ i["doc"] for i in self.postingList[index2]["docs"]])
                        # print(self.postingList[index1]["docs"] , self.postingList[index2]["docs"])
                        return list(docs1.union(docs2))
                    if(index1!=-1): return [ i["doc"] for i in self.postingList[index1]["docs"]] # check if there is result for first word
                    return [ i["doc"] for i in self.postingList[index2]["docs"]] # check if there is result for second word

            else : # near condition
                nearNumber = int(splitQuery[1].split('/')[1]) # find near 
                if(index1!=-1 and index2!=-1): # check if there are result for both of words
                    docs1 =   {i["doc"]:i["indexes"] for i in self.postingList[index1]["docs"]} # find document of word one and make dictionary for result
                    docs2 =   {i["doc"]:i["indexes"] for i in self.postingList[index2]["docs"]} # find document of word two and make dictionary for result

                    result = [] 
                    keysOfDocs2 = docs2.keys()
                    for key, value in docs1.items():
                        if (key in keysOfDocs2):
                            d1 = np.array(value) # indexes of word in first document
                            d2 = np.array(copy.deepcopy(docs2[key])) # indexes of word in second document
                            distanceMatrix = np.array([[abs(i - j )for i in d1] for j in d2]) # distance matrix
                            if (distanceMatrix.min() <= nearNumber): # check validation
                                result.append(key)


                            # example of distanceMatrix
                            # 
                            # [[ 0  1  2 10 11]
                            # [ 1  0  1  9 10]
                            # [ 2  1  0  8  9]
                            # [10  9  8  0  1]
                            # [11 10  9  1  0]]


                    return result
                return []



                        
            

            
        



    def prnt(self):
        for i in self.postingList:
            print(i)

# %% [markdown]
# # My Tests:

# %%
test = searchEngine()

test.input(['text1.txt' , "test.txt"])
# Out:
# document 1 : text1.txt
# document 2 : test.txt

# %%
print(test.find("amirali and aa"))
# Out:
# [2]

# %%
print(test.find("amirali or aa"))
# Out:
# [1, 2]

# %%
print(test.find("amirali or ii"))
# Out:
# [2]

# %%
print(test.find("amirali n/3 amini"))
# Out:
# [2]

# %%
print(test.find("hasani n/3 amini"))
# Out:
# [1]

# %%
print(test.find("aa n/3 aa"))
# Out:
# [1, 2]

# %%
test.prnt()
# Out:
# {'word': 'aa', 'docs': [{'doc': 1, 'indexes': [0, 1, 2, 10, 11]}, {'doc': 2, 'indexes': [6]}]}
# {'word': 'ali', 'docs': [{'doc': 1, 'indexes': [13]}]}
# {'word': 'amini', 'docs': [{'doc': 1, 'indexes': [14]}, {'doc': 2, 'indexes': [1]}]}
# {'word': 'amir', 'docs': [{'doc': 1, 'indexes': [12, 15]}]}
# {'word': 'amirali', 'docs': [{'doc': 2, 'indexes': [0, 4, 5]}]}
# {'word': 'bb', 'docs': [{'doc': 1, 'indexes': [3, 4, 5]}, {'doc': 2, 'indexes': [7]}]}
# {'word': 'hasani', 'docs': [{'doc': 1, 'indexes': [17]}]}
# {'word': 'hastam', 'docs': [{'doc': 2, 'indexes': [2]}]}
# {'word': 'hossein', 'docs': [{'doc': 1, 'indexes': [16]}]}
# {'word': 'mm', 'docs': [{'doc': 1, 'indexes': [8, 9]}]}
# {'word': 'salam', 'docs': [{'doc': 2, 'indexes': [3]}]}
# {'word': 'zz', 'docs': [{'doc': 1, 'indexes': [6, 7]}]}

# %% [markdown]
# # Test Cases:

# %%
testCase  = searchEngine()
testCase.input(['document1.txt','document2.txt','document3.txt'])
# Out:
# document 1 : document1.txt
# document 2 : document2.txt
# document 3 : document3.txt

# %% [markdown]
# ## Boolean Test
# ### Input Boolean Query
#
# expected results = [2, 3]

# %%
testCase.find('example AND content')
# Out:
# [2, 3]

# %% [markdown]
# ## Near
# ### Input proximity Query
#
# expected results proximity = [2]

# %%
testCase.find('example NEAR/3 content')
# Out:
# [2]

# %%
import os

# %%
directory_input = ['docs/'+path for path in os.listdir('docs') if path[-3:] == 'txt']
print(directory_input)
# Out:
# ['docs/Jerry Decided To Buy a Gun.txt', 'docs/Rentals at the Oceanside Community.txt', 'docs/Gasoline Prices Hit Record High.txt', 'docs/Cloning Pets.txt', 'docs/Crazy Housing Prices.txt', 'docs/Man Injured at Fast Food Place.txt', 'docs/A Festival of Books.txt', 'docs/Food Fight Erupted in Prison.txt', 'docs/Better To Be Unlucky.txt', 'docs/Sara Went Shopping.txt', 'docs/Freeway Chase Ends at Newsstand.txt', 'docs/Trees Are a Threat.txt', 'docs/A Murder-Suicide.txt', 'docs/Happy and Unhappy Renters.txt', 'docs/Pulling Out Nine Tons of Trash.txt']

# %% [markdown]
# # docs

# %%
test_directory = searchEngine()
test_directory.input(directory_input)
test_directory.prnt()
# Out:
# document 1 : docs/Jerry Decided To Buy a Gun.txt
# document 2 : docs/Rentals at the Oceanside Community.txt
# document 3 : docs/Gasoline Prices Hit Record High.txt
# document 4 : docs/Cloning Pets.txt
# document 5 : docs/Crazy Housing Prices.txt
# document 6 : docs/Man Injured at Fast Food Place.txt
# document 7 : docs/A Festival of Books.txt
# document 8 : docs/Food Fight Erupted in Prison.txt
# document 9 : docs/Better To Be Unlucky.txt
# document 10 : docs/Sara Went Shopping.txt
# document 11 : docs/Freeway Chase Ends at Newsstand.txt
# document 12 : docs/Trees Are a Threat.txt
# document 13 : docs/A Murder-Suicide.txt
# document 14 : docs/Happy and Unhappy Renters.txt
# document 15 : docs/Pulling Out Nine Tons of Trash.txt
# {'word': '.38', 'docs': [{'doc': 1, 'indexes': [103]}]}
# {'word': '1', 'docs': [{'doc': 3, 'indexes': [120]}]}
# {'word': '1,000', 'docs': [{'doc': 1, 'indexes': [47]}, {'doc': 12, 'indexes': [125]}]}
# {'word': '10', 'docs': [{'doc': 1, 'indexes': [122]}, {'doc': 2, 'indexes': [51]}, {'doc': 3, 'indexes': [58]}, {'doc': 5, 'indexes': [81]}, {'doc': 7, 'indexes': [24]}, {'doc': 10, 'indexes': [77]}]}
# {'word': '1000', 'docs': [{'doc': 9, 'indexes': [117]}]}
# {'word': '1000x', 'docs': [{'doc': 9, 'indexes': [43, 62]}]}
# {'word': '100x', 'docs': [{'doc': 9, 'indexes': [41]}]}
# {'word': '10x', 'docs': [{'doc': 9, 'indexes': [39]}]}
# {'word': '11', 'docs': [{'doc': 12, 'indexes': [87]}]}
# {'word': '110,000', 'docs': [{'doc': 9, 'indexes': [144]}]}
# {'word': '12', 'docs': [{'doc': 3, 'indexes': [21]}]}
# {'word': '120', 'docs': [{'doc': 9, 'indexes': [111, 119]}]}
# {'word': '120,000', 'docs': [{'doc': 9, 'indexes': [20, 120]}]}
# {'word': '15', 'docs': [{'doc': 2, 'indexes': [160]}]}
# {'word': '15-percent', 'docs': [{'doc': 2, 'indexes': [22]}]}
# {'word': '150', 'docs': [{'doc': 7, 'indexes': [82]}, {'doc': 15, 'indexes': [3]}]}
# {'word': '1992.', 'docs': [{'doc': 10, 'indexes': [13]}]}
# {'word': '1993', 'docs': [{'doc': 5, 'indexes': [42]}]}
# {'word': '1995', 'docs': [{'doc': 10, 'indexes': [29]}]}
# {'word': '1x', 'docs': [{'doc': 9, 'indexes': [38]}]}
# {'word': '2,000', 'docs': [{'doc': 2, 'indexes': [38]}]}
# {'word': '2.09', 'docs': [{'doc': 3, 'indexes': [29]}]}
# {'word': '2.14', 'docs': [{'doc': 3, 'indexes': [80]}]}
# {'word': '2.22', 'docs': [{'doc': 3, 'indexes': [15]}]}
# {'word': '20', 'docs': [{'doc': 3, 'indexes': [59, 102]}, {'doc': 13, 'indexes': [68]}]}
# {'word': '20,000', 'docs': [{'doc': 5, 'indexes': [102]}]}
# {'word': '200', 'docs': [{'doc': 2, 'indexes': [143]}]}
# {'word': '230,000', 'docs': [{'doc': 5, 'indexes': [58]}]}
# {'word': '24-year-old', 'docs': [{'doc': 11, 'indexes': [0]}]}
# {'word': '25', 'docs': [{'doc': 9, 'indexes': [15]}]}
# {'word': '25,000', 'docs': [{'doc': 4, 'indexes': [63]}]}
# {'word': '25,000.', 'docs': [{'doc': 4, 'indexes': [88]}]}
# {'word': '280', 'docs': [{'doc': 7, 'indexes': [68]}]}
# {'word': '29.95', 'docs': [{'doc': 10, 'indexes': [50]}]}
# {'word': '3', 'docs': [{'doc': 12, 'indexes': [29]}]}
# {'word': '3.50', 'docs': [{'doc': 10, 'indexes': [68]}]}
# {'word': '30', 'docs': [{'doc': 1, 'indexes': [2]}, {'doc': 3, 'indexes': [17]}, {'doc': 10, 'indexes': [6]}]}
# {'word': '300', 'docs': [{'doc': 1, 'indexes': [106]}]}
# {'word': '3037', 'docs': [{'doc': 10, 'indexes': [8]}]}
# {'word': '39.95', 'docs': [{'doc': 10, 'indexes': [55]}]}
# {'word': '4,000', 'docs': [{'doc': 12, 'indexes': [84]}]}
# {'word': '4,000.residents', 'docs': [{'doc': 12, 'indexes': [43]}]}
# {'word': '5', 'docs': [{'doc': 3, 'indexes': [85]}, {'doc': 5, 'indexes': [20]}]}
# {'word': '50', 'docs': [{'doc': 4, 'indexes': [103, 105]}, {'doc': 10, 'indexes': [71]}, {'doc': 13, 'indexes': [18]}]}
# {'word': '50,000', 'docs': [{'doc': 4, 'indexes': [35]}]}
# {'word': '500', 'docs': [{'doc': 15, 'indexes': [124]}]}
# {'word': '500x', 'docs': [{'doc': 9, 'indexes': [42]}]}
# {'word': '50th', 'docs': [{'doc': 13, 'indexes': [21]}]}
# {'word': '50x', 'docs': [{'doc': 9, 'indexes': [40]}]}
# {'word': '510,000', 'docs': [{'doc': 5, 'indexes': [71]}]}
# {'word': '6,000', 'docs': [{'doc': 12, 'indexes': [4]}]}
# {'word': '60', 'docs': [{'doc': 4, 'indexes': [74]}]}
# {'word': '65-year-old', 'docs': [{'doc': 12, 'indexes': [144]}]}
# {'word': '7', 'docs': [{'doc': 7, 'indexes': [98]}]}
# {'word': '70,000', 'docs': [{'doc': 5, 'indexes': [49]}, {'doc': 7, 'indexes': [62]}]}
# {'word': '70-year-old', 'docs': [{'doc': 13, 'indexes': [13]}]}
# {'word': '74-year-old', 'docs': [{'doc': 13, 'indexes': [9]}]}
# {'word': '75', 'docs': [{'doc': 8, 'indexes': [115]}]}
# {'word': '75,000', 'docs': [{'doc': 7, 'indexes': [64]}]}
# {'word': '76', 'docs': [{'doc': 9, 'indexes': [107]}]}
# {'word': '79-year-old', 'docs': [{'doc': 6, 'indexes': [0]}]}
# {'word': '87', 'docs': [{'doc': 3, 'indexes': [11]}]}
# {'word': '9', 'docs': [{'doc': 10, 'indexes': [33]}]}
# {'word': '9,000', 'docs': [{'doc': 9, 'indexes': [154]}]}
# {'word': '90', 'docs': [{'doc': 7, 'indexes': [70]}]}
# {'word': '99', 'docs': [{'doc': 3, 'indexes': [117]}]}
# {'word': '9:00', 'docs': [{'doc': 6, 'indexes': [20]}]}
# {'word': 'a.m.', 'docs': [{'doc': 10, 'indexes': [34, 78]}]}
# {'word': 'able', 'docs': [{'doc': 6, 'indexes': [90]}]}
# {'word': 'abuse', 'docs': [{'doc': 2, 'indexes': [90]}]}
# {'word': 'accidentally', 'docs': [{'doc': 1, 'indexes': [124]}, {'doc': 6, 'indexes': [25]}]}
# {'word': 'according', 'docs': [{'doc': 13, 'indexes': [26]}]}
# {'word': 'acres', 'docs': [{'doc': 12, 'indexes': [85]}]}
# {'word': 'actually', 'docs': [{'doc': 4, 'indexes': [7]}]}
# {'word': 'administration', 'docs': [{'doc': 8, 'indexes': [108]}]}
# {'word': 'afghan', 'docs': [{'doc': 9, 'indexes': [11]}]}
# {'word': 'agency', 'docs': [{'doc': 13, 'indexes': [167]}]}
# {'word': 'ago', 'docs': [{'doc': 2, 'indexes': [53]}, {'doc': 3, 'indexes': [23, 47]}, {'doc': 7, 'indexes': [144]}, {'doc': 8, 'indexes': [15]}, {'doc': 13, 'indexes': [25, 97]}]}
# {'word': 'aid', 'docs': [{'doc': 6, 'indexes': [37]}]}
# {'word': 'alan', 'docs': [{'doc': 15, 'indexes': [24]}]}
# {'word': 'allen', 'docs': [{'doc': 13, 'indexes': [30, 62, 152]}]}
# {'word': 'allotments', 'docs': [{'doc': 8, 'indexes': [114]}]}
# {'word': 'allow', 'docs': [{'doc': 2, 'indexes': [6]}]}
# {'word': 'allowing', 'docs': [{'doc': 2, 'indexes': [48]}]}
# {'word': 'almost', 'docs': [{'doc': 2, 'indexes': [103]}, {'doc': 3, 'indexes': [16]}, {'doc': 13, 'indexes': [53, 159]}, {'doc': 15, 'indexes': [14]}]}
# {'word': 'alone', 'docs': [{'doc': 13, 'indexes': [192]}]}
# {'word': 'along', 'docs': [{'doc': 15, 'indexes': [112]}]}
# {'word': 'already', 'docs': [{'doc': 2, 'indexes': [131, 190]}, {'doc': 4, 'indexes': [23]}, {'doc': 7, 'indexes': [152]}, {'doc': 13, 'indexes': [46]}]}
# {'word': 'also', 'docs': [{'doc': 1, 'indexes': [107]}, {'doc': 2, 'indexes': [44]}, {'doc': 9, 'indexes': [157]}, {'doc': 11, 'indexes': [77]}, {'doc': 14, 'indexes': [84]}]}
# {'word': 'altadena', 'docs': [{'doc': 13, 'indexes': [7]}]}
# {'word': 'although', 'docs': [{'doc': 7, 'indexes': [149]}, {'doc': 15, 'indexes': [135]}]}
# {'word': 'always', 'docs': [{'doc': 5, 'indexes': [175, 188]}, {'doc': 13, 'indexes': [73, 84]}, {'doc': 14, 'indexes': [26, 37]}]}
# {'word': 'ambulance', 'docs': [{'doc': 11, 'indexes': [150]}]}
# {'word': 'american', 'docs': [{'doc': 7, 'indexes': [91]}]}
# {'word': 'ammunition', 'docs': [{'doc': 1, 'indexes': [111]}]}
# {'word': 'among', 'docs': [{'doc': 7, 'indexes': [131]}]}
# {'word': 'amount', 'docs': [{'doc': 4, 'indexes': [62]}]}
# {'word': 'amounts', 'docs': [{'doc': 2, 'indexes': [72]}]}
# {'word': 'amputated', 'docs': [{'doc': 13, 'indexes': [49]}]}
# {'word': 'angelenos', 'docs': [{'doc': 7, 'indexes': [163]}]}
# {'word': 'angeles', 'docs': [{'doc': 7, 'indexes': [4, 35, 158]}, {'doc': 11, 'indexes': [2, 19]}]}
# {'word': 'anniversary', 'docs': [{'doc': 13, 'indexes': [22]}]}
# {'word': 'annual', 'docs': [{'doc': 7, 'indexes': [30]}, {'doc': 14, 'indexes': [8]}]}
# {'word': 'another', 'docs': [{'doc': 2, 'indexes': [81]}, {'doc': 14, 'indexes': [20, 110, 116]}]}
# {'word': 'antennas', 'docs': [{'doc': 15, 'indexes': [71]}]}
# {'word': 'anyone', 'docs': [{'doc': 5, 'indexes': [98]}]}
# {'word': 'anything', 'docs': [{'doc': 15, 'indexes': [132]}]}
# {'word': 'apartment', 'docs': [{'doc': 1, 'indexes': [9]}]}
# {'word': 'apartments', 'docs': [{'doc': 14, 'indexes': [66]}]}
# {'word': 'apparent', 'docs': [{'doc': 13, 'indexes': [3]}]}
# {'word': 'appears', 'docs': [{'doc': 9, 'indexes': [55]}]}
# {'word': 'appliances', 'docs': [{'doc': 13, 'indexes': [82]}]}
# {'word': 'apply', 'docs': [{'doc': 12, 'indexes': [133]}]}
# {'word': 'approved', 'docs': [{'doc': 8, 'indexes': [102]}]}
# {'word': 'april', 'docs': [{'doc': 7, 'indexes': [55]}]}
# {'word': 'arcadia', 'docs': [{'doc': 3, 'indexes': [33]}]}
# {'word': 'area', 'docs': [{'doc': 12, 'indexes': [39, 67, 77]}]}
# {'word': 'arizona', 'docs': [{'doc': 4, 'indexes': [2]}]}
# {'word': 'around', 'docs': [{'doc': 3, 'indexes': [148]}, {'doc': 5, 'indexes': [19]}]}
# {'word': 'arrived', 'docs': [{'doc': 10, 'indexes': [75]}]}
# {'word': 'asked', 'docs': [{'doc': 3, 'indexes': [104]}, {'doc': 12, 'indexes': [142]}]}
# {'word': 'asking', 'docs': [{'doc': 5, 'indexes': [83]}]}
# {'word': 'assisted', 'docs': [{'doc': 15, 'indexes': [103]}]}
# {'word': 'attendance', 'docs': [{'doc': 7, 'indexes': [60]}]}
# {'word': 'attitudes', 'docs': [{'doc': 14, 'indexes': [135]}]}
# {'word': 'attract', 'docs': [{'doc': 11, 'indexes': [55]}]}
# {'word': 'audience', 'docs': [{'doc': 7, 'indexes': [74]}]}
# {'word': 'authors', 'docs': [{'doc': 7, 'indexes': [73, 83, 134]}]}
# {'word': 'auto', 'docs': [{'doc': 15, 'indexes': [56]}]}
# {'word': 'autograph', 'docs': [{'doc': 7, 'indexes': [79]}]}
# {'word': 'available.this', 'docs': [{'doc': 7, 'indexes': [48]}]}
# {'word': 'avenue', 'docs': [{'doc': 9, 'indexes': [78]}, {'doc': 11, 'indexes': [64]}]}
# {'word': 'average', 'docs': [{'doc': 3, 'indexes': [9]}]}
# {'word': 'avoid', 'docs': [{'doc': 11, 'indexes': [92]}]}
# {'word': 'avoided', 'docs': [{'doc': 7, 'indexes': [105]}]}
# {'word': 'away', 'docs': [{'doc': 3, 'indexes': [79, 108]}]}
# {'word': 'away.barget', 'docs': [{'doc': 10, 'indexes': [43]}]}
# {'word': 'baby', 'docs': [{'doc': 15, 'indexes': [68]}]}
# {'word': 'back', 'docs': [{'doc': 8, 'indexes': [52]}, {'doc': 10, 'indexes': [73]}, {'doc': 11, 'indexes': [112]}, {'doc': 12, 'indexes': [165]}, {'doc': 15, 'indexes': [32]}]}
# {'word': 'backbreaking', 'docs': [{'doc': 15, 'indexes': [81]}]}
# {'word': 'bad', 'docs': [{'doc': 12, 'indexes': [66]}]}
# {'word': 'bag', 'docs': [{'doc': 15, 'indexes': [76]}]}
# {'word': 'bags', 'docs': [{'doc': 8, 'indexes': [89]}, {'doc': 15, 'indexes': [66, 128]}]}
# {'word': 'baldwin', 'docs': [{'doc': 1, 'indexes': [1]}]}
# {'word': 'balls', 'docs': [{'doc': 15, 'indexes': [64]}]}
# {'word': 'ban', 'docs': [{'doc': 2, 'indexes': [186]}]}
# {'word': 'ban.city', 'docs': [{'doc': 2, 'indexes': [119]}]}
# {'word': 'band', 'docs': [{'doc': 14, 'indexes': [59]}]}
# {'word': 'bang', 'docs': [{'doc': 11, 'indexes': [66]}]}
# {'word': 'barco', 'docs': [{'doc': 3, 'indexes': [76]}]}
# {'word': 'barget', 'docs': [{'doc': 10, 'indexes': [39]}]}
# {'word': 'barney', 'docs': [{'doc': 1, 'indexes': [40]}]}
# {'word': 'bartering', 'docs': [{'doc': 8, 'indexes': [36]}]}
# {'word': 'basic', 'docs': [{'doc': 8, 'indexes': [57]}]}
# {'word': 'basis', 'docs': [{'doc': 2, 'indexes': [11]}]}
# {'word': 'batteries', 'docs': [{'doc': 15, 'indexes': [57]}]}
# {'word': 'bay', 'docs': [{'doc': 15, 'indexes': [94]}]}
# {'word': 'beach', 'docs': [{'doc': 2, 'indexes': [3]}, {'doc': 5, 'indexes': [40, 91]}]}
# {'word': 'become', 'docs': [{'doc': 7, 'indexes': [47]}]}
# {'word': 'behind', 'docs': [{'doc': 11, 'indexes': [139]}]}
# {'word': 'believes', 'docs': [{'doc': 4, 'indexes': [121]}]}
# {'word': 'beloved', 'docs': [{'doc': 4, 'indexes': [20]}]}
# {'word': 'berserk', 'docs': [{'doc': 8, 'indexes': [66]}]}
# {'word': 'best', 'docs': [{'doc': 14, 'indexes': [107]}]}
# {'word': 'better', 'docs': [{'doc': 9, 'indexes': [139, 171]}, {'doc': 14, 'indexes': [100]}]}
# {'word': 'bicycles', 'docs': [{'doc': 15, 'indexes': [53]}]}
# {'word': 'big', 'docs': [{'doc': 8, 'indexes': [88]}, {'doc': 9, 'indexes': [21]}, {'doc': 12, 'indexes': [168]}, {'doc': 15, 'indexes': [125]}]}
# {'word': 'bigger', 'docs': [{'doc': 9, 'indexes': [19]}]}
# {'word': 'bikers', 'docs': [{'doc': 12, 'indexes': [72]}]}
# {'word': 'bill', 'docs': [{'doc': 9, 'indexes': [143]}]}
# {'word': 'binoculars.', 'docs': [{'doc': 14, 'indexes': [130]}]}
# {'word': 'biopsy', 'docs': [{'doc': 4, 'indexes': [39]}]}
# {'word': 'birder', 'docs': [{'doc': 14, 'indexes': [125]}]}
# {'word': 'birding', 'docs': [{'doc': 14, 'indexes': [127]}]}
# {'word': 'births', 'docs': [{'doc': 4, 'indexes': [99]}]}
# {'word': 'bizarre', 'docs': [{'doc': 4, 'indexes': [118]}]}
# {'word': 'black', 'docs': [{'doc': 1, 'indexes': [55]}]}
# {'word': 'blanket', 'docs': [{'doc': 9, 'indexes': [12]}]}
# {'word': 'blind', 'docs': [{'doc': 13, 'indexes': [40]}]}
# {'word': 'block', 'docs': [{'doc': 3, 'indexes': [66, 78, 107]}]}
# {'word': 'blocks', 'docs': [{'doc': 11, 'indexes': [125]}]}
# {'word': 'blue', 'docs': [{'doc': 10, 'indexes': [31]}]}
# {'word': 'bob', 'docs': [{'doc': 10, 'indexes': [21]}]}
# {'word': 'book', 'docs': [{'doc': 7, 'indexes': [31, 150]}]}
# {'word': 'books', 'docs': [{'doc': 7, 'indexes': [17, 133]}, {'doc': 11, 'indexes': [49]}]}
# {'word': 'bookstore', 'docs': [{'doc': 11, 'indexes': [57]}]}
# {'word': 'boon', 'docs': [{'doc': 2, 'indexes': [26]}]}
# {'word': 'boots', 'docs': [{'doc': 15, 'indexes': [106]}]}
# {'word': 'born', 'docs': [{'doc': 4, 'indexes': [73]}]}
# {'word': 'bottle', 'docs': [{'doc': 11, 'indexes': [27]}]}
# {'word': 'bottles', 'docs': [{'doc': 15, 'indexes': [52]}]}
# {'word': 'bought', 'docs': [{'doc': 1, 'indexes': [101, 108]}, {'doc': 3, 'indexes': [42, 115]}, {'doc': 5, 'indexes': [43]}, {'doc': 10, 'indexes': [47]}]}
# {'word': 'bowling', 'docs': [{'doc': 15, 'indexes': [63]}]}
# {'word': 'boxes', 'docs': [{'doc': 1, 'indexes': [110]}]}
# {'word': 'boy', 'docs': [{'doc': 9, 'indexes': [85]}, {'doc': 15, 'indexes': [89, 137]}]}
# {'word': 'braked', 'docs': [{'doc': 11, 'indexes': [114]}]}
# {'word': 'brakes', 'docs': [{'doc': 11, 'indexes': [91]}]}
# {'word': 'brand', 'docs': [{'doc': 6, 'indexes': [6]}]}
# {'word': 'breakfast', 'docs': [{'doc': 10, 'indexes': [87]}]}
# {'word': 'bring', 'docs': [{'doc': 2, 'indexes': [37]}, {'doc': 5, 'indexes': [156]}, {'doc': 14, 'indexes': [106]}]}
# {'word': 'brown', 'docs': [{'doc': 2, 'indexes': [31]}]}
# {'word': 'brush', 'docs': [{'doc': 12, 'indexes': [31]}]}
# {'word': 'bubble', 'docs': [{'doc': 5, 'indexes': [142]}]}
# {'word': 'budget', 'docs': [{'doc': 2, 'indexes': [115]}]}
# {'word': 'bulbs', 'docs': [{'doc': 13, 'indexes': [80]}]}
# {'word': 'bullet', 'docs': [{'doc': 1, 'indexes': [129]}]}
# {'word': 'bummer', 'docs': [{'doc': 3, 'indexes': [118]}]}
# {'word': 'burger', 'docs': [{'doc': 6, 'indexes': [11, 79]}]}
# {'word': 'burn', 'docs': [{'doc': 6, 'indexes': [19]}]}
# {'word': 'burned', 'docs': [{'doc': 12, 'indexes': [83]}]}
# {'word': 'burst', 'docs': [{'doc': 5, 'indexes': [143, 147]}]}
# {'word': 'bus', 'docs': [{'doc': 11, 'indexes': [89, 94, 96, 111]}]}
# {'word': 'bus.jerry', 'docs': [{'doc': 1, 'indexes': [18]}]}
# {'word': 'buy', 'docs': [{'doc': 1, 'indexes': [38]}, {'doc': 5, 'indexes': [119, 121, 128, 133]}, {'doc': 10, 'indexes': [63]}, {'doc': 15, 'indexes': [157]}]}
# {'word': 'caliber', 'docs': [{'doc': 1, 'indexes': [104]}]}
# {'word': 'california', 'docs': [{'doc': 3, 'indexes': [2]}, {'doc': 7, 'indexes': [113]}]}
# {'word': 'california.', 'docs': [{'doc': 5, 'indexes': [30]}]}
# {'word': 'called', 'docs': [{'doc': 11, 'indexes': [149]}, {'doc': 13, 'indexes': [180]}, {'doc': 14, 'indexes': [60]}]}
# {'word': 'came', 'docs': [{'doc': 1, 'indexes': [24]}, {'doc': 7, 'indexes': [112]}, {'doc': 9, 'indexes': [97]}, {'doc': 13, 'indexes': [99, 162]}, {'doc': 14, 'indexes': [39]}, {'doc': 15, 'indexes': [47]}]}
# {'word': 'candy', 'docs': [{'doc': 8, 'indexes': [30, 34, 90, 105]}, {'doc': 13, 'indexes': [92]}]}
# {'word': 'cane', 'docs': [{'doc': 1, 'indexes': [137]}]}
# {'word': 'canine', 'docs': [{'doc': 4, 'indexes': [114]}]}
# {'word': 'cans', 'docs': [{'doc': 15, 'indexes': [51]}]}
# {'word': 'canton', 'docs': [{'doc': 12, 'indexes': [2, 94]}]}
# {'word': 'captured', 'docs': [{'doc': 8, 'indexes': [12]}]}
# {'word': 'car', 'docs': [{'doc': 7, 'indexes': [27]}, {'doc': 9, 'indexes': [149]}, {'doc': 10, 'indexes': [37]}, {'doc': 14, 'indexes': [122]}, {'doc': 15, 'indexes': [54]}]}
# {'word': 'car.sam', 'docs': [{'doc': 9, 'indexes': [136]}]}
# {'word': 'careful', 'docs': [{'doc': 2, 'indexes': [150]}]}
# {'word': 'carpenter', 'docs': [{'doc': 13, 'indexes': [38]}]}
# {'word': 'carriages', 'docs': [{'doc': 15, 'indexes': [69]}]}
# {'word': 'cars', 'docs': [{'doc': 2, 'indexes': [68]}, {'doc': 3, 'indexes': [65]}, {'doc': 9, 'indexes': [70]}, {'doc': 11, 'indexes': [69, 74, 102, 118]}]}
# {'word': 'carson', 'docs': [{'doc': 15, 'indexes': [12]}]}
# {'word': 'carts', 'docs': [{'doc': 11, 'indexes': [51]}, {'doc': 15, 'indexes': [62]}]}
# {'word': 'cat', 'docs': [{'doc': 4, 'indexes': [5, 21, 33, 40, 68]}]}
# {'word': 'cataract', 'docs': [{'doc': 13, 'indexes': [43]}]}
# {'word': 'cause', 'docs': [{'doc': 2, 'indexes': [148, 198]}]}
# {'word': 'caused', 'docs': [{'doc': 11, 'indexes': [88]}]}
# {'word': 'causing', 'docs': [{'doc': 11, 'indexes': [46]}]}
# {'word': 'cell', 'docs': [{'doc': 4, 'indexes': [65]}, {'doc': 9, 'indexes': [128]}]}
# {'word': 'cells', 'docs': [{'doc': 4, 'indexes': [48, 50]}]}
# {'word': 'cents', 'docs': [{'doc': 3, 'indexes': [86]}, {'doc': 10, 'indexes': [72]}]}
# {'word': 'certificates–one', 'docs': [{'doc': 6, 'indexes': [57]}]}
# {'word': 'change', 'docs': [{'doc': 9, 'indexes': [87]}]}
# {'word': 'change.sara', 'docs': [{'doc': 10, 'indexes': [74]}]}
# {'word': 'changed', 'docs': [{'doc': 14, 'indexes': [120]}]}
# {'word': 'changing', 'docs': [{'doc': 13, 'indexes': [78]}]}
# {'word': 'channels', 'docs': [{'doc': 9, 'indexes': [89]}]}
# {'word': 'charged', 'docs': [{'doc': 2, 'indexes': [142]}, {'doc': 11, 'indexes': [151]}]}
# {'word': 'chase', 'docs': [{'doc': 11, 'indexes': [12, 15, 23]}]}
# {'word': 'chase.they', 'docs': [{'doc': 11, 'indexes': [122]}]}
# {'word': 'cheap', 'docs': [{'doc': 3, 'indexes': [123]}]}
# {'word': 'cheaper', 'docs': [{'doc': 3, 'indexes': [40]}]}
# {'word': 'check', 'docs': [{'doc': 10, 'indexes': [57]}]}
# {'word': 'chef', 'docs': [{'doc': 14, 'indexes': [104]}]}
# {'word': 'childless', 'docs': [{'doc': 13, 'indexes': [32]}]}
# {'word': 'children', 'docs': [{'doc': 10, 'indexes': [20]}]}
# {'word': 'choose', 'docs': [{'doc': 9, 'indexes': [64]}]}
# {'word': 'church', 'docs': [{'doc': 9, 'indexes': [13]}]}
# {'word': 'cigarettes', 'docs': [{'doc': 8, 'indexes': [40]}]}
# {'word': 'cigars', 'docs': [{'doc': 8, 'indexes': [41]}]}
# {'word': 'cities', 'docs': [{'doc': 7, 'indexes': [155]}]}
# {'word': 'city', 'docs': [{'doc': 2, 'indexes': [18, 32, 46, 98, 113, 138, 156, 171, 178]}, {'doc': 7, 'indexes': [22]}]}
# {'word': 'clean', 'docs': [{'doc': 15, 'indexes': [11]}]}
# {'word': 'cleared', 'docs': [{'doc': 12, 'indexes': [37, 68, 76]}]}
# {'word': 'clearing', 'docs': [{'doc': 12, 'indexes': [107, 111]}]}
# {'word': 'clicked', 'docs': [{'doc': 9, 'indexes': [110]}]}
# {'word': 'clients', 'docs': [{'doc': 4, 'indexes': [24]}]}
# {'word': 'clockwork', 'docs': [{'doc': 14, 'indexes': [12]}]}
# {'word': 'clone', 'docs': [{'doc': 4, 'indexes': [4, 26, 32, 58]}]}
# {'word': 'clones', 'docs': [{'doc': 4, 'indexes': [115]}]}
# {'word': 'cloning', 'docs': [{'doc': 4, 'indexes': [123]}]}
# {'word': 'close', 'docs': [{'doc': 13, 'indexes': [33]}]}
# {'word': 'clothing', 'docs': [{'doc': 15, 'indexes': [60]}]}
# {'word': 'club', 'docs': [{'doc': 1, 'indexes': [117, 121]}]}
# {'word': 'clubs.much', 'docs': [{'doc': 15, 'indexes': [80]}]}
# {'word': 'coffee', 'docs': [{'doc': 6, 'indexes': [28, 32, 59]}]}
# {'word': 'coffers', 'docs': [{'doc': 2, 'indexes': [27]}]}
# {'word': 'coin', 'docs': [{'doc': 9, 'indexes': [96]}]}
# {'word': 'collection', 'docs': [{'doc': 1, 'indexes': [46]}]}
# {'word': 'collision', 'docs': [{'doc': 11, 'indexes': [93]}]}
# {'word': 'color', 'docs': [{'doc': 1, 'indexes': [54]}, {'doc': 14, 'indexes': [159]}]}
# {'word': 'colors', 'docs': [{'doc': 15, 'indexes': [50]}]}
# {'word': 'come', 'docs': [{'doc': 5, 'indexes': [171]}, {'doc': 11, 'indexes': [129]}, {'doc': 13, 'indexes': [114]}, {'doc': 14, 'indexes': [54]}, {'doc': 15, 'indexes': [31]}]}
# {'word': 'comic', 'docs': [{'doc': 7, 'indexes': [16]}]}
# {'word': 'community', 'docs': [{'doc': 2, 'indexes': [1, 122, 189]}, {'doc': 15, 'indexes': [85]}]}
# {'word': 'company', 'docs': [{'doc': 4, 'indexes': [0, 91, 109]}, {'doc': 9, 'indexes': [146]}]}
# {'word': 'complain', 'docs': [{'doc': 14, 'indexes': [156]}]}
# {'word': 'complaints', 'docs': [{'doc': 2, 'indexes': [107, 140]}]}
# {'word': 'completely', 'docs': [{'doc': 13, 'indexes': [54]}]}
# {'word': 'complex', 'docs': [{'doc': 8, 'indexes': [10]}]}
# {'word': 'complications', 'docs': [{'doc': 13, 'indexes': [50]}]}
# {'word': 'complied', 'docs': [{'doc': 8, 'indexes': [97]}]}
# {'word': 'concerned', 'docs': [{'doc': 15, 'indexes': [97]}]}
# {'word': 'condo', 'docs': [{'doc': 5, 'indexes': [69, 89]}]}
# {'word': 'condominium', 'docs': [{'doc': 5, 'indexes': [47]}]}
# {'word': 'cone', 'docs': [{'doc': 15, 'indexes': [161]}]}
# {'word': 'cons', 'docs': [{'doc': 2, 'indexes': [128]}]}
# {'word': 'considerate', 'docs': [{'doc': 2, 'indexes': [154]}]}
# {'word': 'consideration', 'docs': [{'doc': 2, 'indexes': [192]}]}
# {'word': 'consisting', 'docs': [{'doc': 15, 'indexes': [2]}]}
# {'word': 'contestant', 'docs': [{'doc': 9, 'indexes': [27, 45]}]}
# {'word': 'continued', 'docs': [{'doc': 2, 'indexes': [187]}]}
# {'word': 'conversations', 'docs': [{'doc': 13, 'indexes': [135]}]}
# {'word': 'convertible', 'docs': [{'doc': 6, 'indexes': [8]}]}
# {'word': 'correct', 'docs': [{'doc': 9, 'indexes': [44]}]}
# {'word': 'correctional', 'docs': [{'doc': 8, 'indexes': [3]}]}
# {'word': 'correctly', 'docs': [{'doc': 9, 'indexes': [60]}]}
# {'word': 'cost', 'docs': [{'doc': 4, 'indexes': [34]}, {'doc': 12, 'indexes': [28]}]}
# {'word': 'could', 'docs': [{'doc': 1, 'indexes': [61]}, {'doc': 13, 'indexes': [146]}]}
# {'word': 'counts', 'docs': [{'doc': 3, 'indexes': [114]}]}
# {'word': 'county', 'docs': [{'doc': 11, 'indexes': [6]}]}
# {'word': 'couple', 'docs': [{'doc': 1, 'indexes': [96, 109]}, {'doc': 7, 'indexes': [115]}, {'doc': 13, 'indexes': [16, 31, 58]}]}
# {'word': 'course', 'docs': [{'doc': 3, 'indexes': [89]}, {'doc': 15, 'indexes': [37]}]}
# {'word': 'court', 'docs': [{'doc': 7, 'indexes': [85, 107]}]}
# {'word': 'crazy', 'docs': [{'doc': 5, 'indexes': [33]}]}
# {'word': 'cream', 'docs': [{'doc': 15, 'indexes': [160]}]}
# {'word': 'created', 'docs': [{'doc': 2, 'indexes': [91]}]}
# {'word': 'creek', 'docs': [{'doc': 15, 'indexes': [13]}]}
# {'word': 'crew', 'docs': [{'doc': 15, 'indexes': [1]}]}
# {'word': 'crews', 'docs': [{'doc': 2, 'indexes': [100]}]}
# {'word': 'crossing', 'docs': [{'doc': 9, 'indexes': [130]}]}
# {'word': 'crosswalk', 'docs': [{'doc': 11, 'indexes': [83]}]}
# {'word': 'cub', 'docs': [{'doc': 15, 'indexes': [87]}]}
# {'word': 'cube', 'docs': [{'doc': 9, 'indexes': [22, 33, 35, 56]}]}
# {'word': 'cultured', 'docs': [{'doc': 4, 'indexes': [44, 64]}]}
# {'word': 'cup', 'docs': [{'doc': 6, 'indexes': [27]}]}
# {'word': 'currently', 'docs': [{'doc': 4, 'indexes': [110]}]}
# {'word': 'customers', 'docs': [{'doc': 11, 'indexes': [56]}]}
# {'word': 'customers.the', 'docs': [{'doc': 3, 'indexes': [52]}]}
# {'word': 'cut', 'docs': [{'doc': 8, 'indexes': [32, 51]}, {'doc': 12, 'indexes': [126]}]}
# {'word': 'cutting', 'docs': [{'doc': 12, 'indexes': [110]}]}
# {'word': 'cycles', 'docs': [{'doc': 5, 'indexes': [162]}]}
# {'word': 'daily', 'docs': [{'doc': 8, 'indexes': [112]}]}
# {'word': 'damage', 'docs': [{'doc': 11, 'indexes': [117]}]}
# {'word': 'day', 'docs': [{'doc': 5, 'indexes': [148]}, {'doc': 14, 'indexes': [50, 69, 79]}, {'doc': 15, 'indexes': [163]}]}
# {'word': 'days', 'docs': [{'doc': 4, 'indexes': [75]}]}
# {'word': 'deal', 'docs': [{'doc': 8, 'indexes': [103]}]}
# {'word': 'deals', 'docs': [{'doc': 7, 'indexes': [137]}]}
# {'word': 'death', 'docs': [{'doc': 13, 'indexes': [177]}]}
# {'word': 'debating', 'docs': [{'doc': 2, 'indexes': [4]}]}
# {'word': 'debris', 'docs': [{'doc': 15, 'indexes': [17, 116]}]}
# {'word': 'decide', 'docs': [{'doc': 5, 'indexes': [118, 120]}]}
# {'word': 'decided', 'docs': [{'doc': 1, 'indexes': [88]}]}
# {'word': 'decision', 'docs': [{'doc': 5, 'indexes': [127]}]}
# {'word': 'decision.finally', 'docs': [{'doc': 9, 'indexes': [93]}]}
# {'word': 'delightful', 'docs': [{'doc': 14, 'indexes': [114, 146]}]}
# {'word': 'delivered', 'docs': [{'doc': 13, 'indexes': [165]}]}
# {'word': 'delivers', 'docs': [{'doc': 4, 'indexes': [84]}]}
# {'word': 'demanding', 'docs': [{'doc': 8, 'indexes': [87]}]}
# {'word': 'demands', 'docs': [{'doc': 8, 'indexes': [98]}]}
# {'word': 'department', 'docs': [{'doc': 10, 'indexes': [40]}]}
# {'word': 'departments', 'docs': [{'doc': 15, 'indexes': [102]}]}
# {'word': 'desperate', 'docs': [{'doc': 5, 'indexes': [115]}]}
# {'word': 'destroyed', 'docs': [{'doc': 12, 'indexes': [86]}]}
# {'word': 'details', 'docs': [{'doc': 1, 'indexes': [78]}]}
# {'word': 'diabetes', 'docs': [{'doc': 13, 'indexes': [100]}]}
# {'word': 'diabetic', 'docs': [{'doc': 13, 'indexes': [45]}]}
# {'word': 'dictionaries', 'docs': [{'doc': 8, 'indexes': [45]}]}
# {'word': 'died', 'docs': [{'doc': 13, 'indexes': [2]}]}
# {'word': 'dies', 'docs': [{'doc': 4, 'indexes': [22]}]}
# {'word': 'different', 'docs': [{'doc': 11, 'indexes': [105]}, {'doc': 14, 'indexes': [132, 134]}]}
# {'word': 'dining', 'docs': [{'doc': 8, 'indexes': [23]}]}
# {'word': 'directions', 'docs': [{'doc': 11, 'indexes': [106]}]}
# {'word': 'director', 'docs': [{'doc': 1, 'indexes': [65]}, {'doc': 5, 'indexes': [166]}, {'doc': 15, 'indexes': [26]}]}
# {'word': 'dirt', 'docs': [{'doc': 12, 'indexes': [71]}]}
# {'word': 'discovered', 'docs': [{'doc': 8, 'indexes': [29]}]}
# {'word': 'disease', 'docs': [{'doc': 13, 'indexes': [51]}]}
# {'word': 'dogs', 'docs': [{'doc': 4, 'indexes': [113, 124]}]}
# {'word': 'dollars', 'docs': [{'doc': 15, 'indexes': [144]}]}
# {'word': 'dolls', 'docs': [{'doc': 15, 'indexes': [67]}]}
# {'word': 'dom', 'docs': [{'doc': 13, 'indexes': [72, 103]}]}
# {'word': 'dominic', 'docs': [{'doc': 13, 'indexes': [10]}]}
# {'word': 'donate', 'docs': [{'doc': 15, 'indexes': [150]}]}
# {'word': 'done', 'docs': [{'doc': 15, 'indexes': [21, 83]}]}
# {'word': 'donna', 'docs': [{'doc': 5, 'indexes': [85]}]}
# {'word': 'donor.', 'docs': [{'doc': 4, 'indexes': [28]}]}
# {'word': 'door', 'docs': [{'doc': 8, 'indexes': [81]}]}
# {'word': 'door-slammer', 'docs': [{'doc': 14, 'indexes': [36]}]}
# {'word': 'doors', 'docs': [{'doc': 8, 'indexes': [72]}]}
# {'word': 'downtown', 'docs': [{'doc': 11, 'indexes': [17, 36]}]}
# {'word': 'dozen', 'docs': [{'doc': 4, 'indexes': [98]}]}
# {'word': 'dreamily', 'docs': [{'doc': 9, 'indexes': [122]}]}
# {'word': 'drinks', 'docs': [{'doc': 7, 'indexes': [96]}]}
# {'word': 'drinks.people', 'docs': [{'doc': 7, 'indexes': [111]}]}
# {'word': 'drive', 'docs': [{'doc': 3, 'indexes': [69, 140, 142, 147]}]}
# {'word': 'drive-through', 'docs': [{'doc': 6, 'indexes': [9]}]}
# {'word': 'driver', 'docs': [{'doc': 11, 'indexes': [29, 34, 58, 76, 87, 97, 135, 145, 152]}]}
# {'word': 'drivers', 'docs': [{'doc': 11, 'indexes': [113]}]}
# {'word': 'driving', 'docs': [{'doc': 11, 'indexes': [157]}]}
# {'word': 'drizzle', 'docs': [{'doc': 15, 'indexes': [9]}]}
# {'word': 'dropped', 'docs': [{'doc': 1, 'indexes': [125]}]}
# {'word': 'drought', 'docs': [{'doc': 12, 'indexes': [13]}]}
# {'word': 'drove', 'docs': [{'doc': 6, 'indexes': [48]}, {'doc': 7, 'indexes': [116]}, {'doc': 10, 'indexes': [38]}]}
# {'word': 'early', 'docs': [{'doc': 11, 'indexes': [115]}]}
# {'word': 'earring', 'docs': [{'doc': 15, 'indexes': [139]}]}
# {'word': 'economy', 'docs': [{'doc': 3, 'indexes': [13]}]}
# {'word': 'eight', 'docs': [{'doc': 3, 'indexes': [127]}, {'doc': 4, 'indexes': [80]}, {'doc': 13, 'indexes': [95]}, {'doc': 15, 'indexes': [6]}]}
# {'word': 'either', 'docs': [{'doc': 13, 'indexes': [157]}]}
# {'word': 'elevation', 'docs': [{'doc': 12, 'indexes': [3]}]}
# {'word': 'elsewhere', 'docs': [{'doc': 3, 'indexes': [41]}]}
# {'word': 'embrace', 'docs': [{'doc': 7, 'indexes': [160]}]}
# {'word': 'emphysema', 'docs': [{'doc': 13, 'indexes': [39]}]}
# {'word': 'employee', 'docs': [{'doc': 6, 'indexes': [24, 66]}]}
# {'word': 'empty', 'docs': [{'doc': 11, 'indexes': [26, 95]}]}
# {'word': 'ended', 'docs': [{'doc': 11, 'indexes': [16]}]}
# {'word': 'ending', 'docs': [{'doc': 13, 'indexes': [184]}]}
# {'word': 'english', 'docs': [{'doc': 1, 'indexes': [57]}]}
# {'word': 'enough', 'docs': [{'doc': 11, 'indexes': [116]}]}
# {'word': 'environmental', 'docs': [{'doc': 15, 'indexes': [92]}]}
# {'word': 'erupted', 'docs': [{'doc': 8, 'indexes': [27]}]}
# {'word': 'estimated', 'docs': [{'doc': 7, 'indexes': [61]}]}
# {'word': 'estrus', 'docs': [{'doc': 4, 'indexes': [69]}]}
# {'word': 'ethnic', 'docs': [{'doc': 7, 'indexes': [89]}]}
# {'word': 'even', 'docs': [{'doc': 2, 'indexes': [58, 164]}, {'doc': 3, 'indexes': [124]}, {'doc': 4, 'indexes': [18]}, {'doc': 5, 'indexes': [151]}, {'doc': 7, 'indexes': [103]}, {'doc': 13, 'indexes': [155, 163]}, {'doc': 15, 'indexes': [74]}]}
# {'word': 'evening', 'docs': [{'doc': 6, 'indexes': [72]}]}
# {'word': 'event', 'docs': [{'doc': 15, 'indexes': [27]}]}
# {'word': 'ever', 'docs': [{'doc': 9, 'indexes': [7]}]}
# {'word': 'everett', 'docs': [{'doc': 3, 'indexes': [36, 70]}]}
# {'word': 'every', 'docs': [{'doc': 2, 'indexes': [88]}, {'doc': 3, 'indexes': [112]}, {'doc': 7, 'indexes': [54]}, {'doc': 13, 'indexes': [88]}, {'doc': 14, 'indexes': [13, 128]}, {'doc': 15, 'indexes': [162]}]}
# {'word': 'everyone', 'docs': [{'doc': 5, 'indexes': [11, 140, 145]}, {'doc': 7, 'indexes': [6]}, {'doc': 10, 'indexes': [88]}, {'doc': 15, 'indexes': [104]}]}
# {'word': 'exact', 'docs': [{'doc': 5, 'indexes': [68]}]}
# {'word': 'except', 'docs': [{'doc': 7, 'indexes': [97]}, {'doc': 11, 'indexes': [25]}]}
# {'word': 'exchange', 'docs': [{'doc': 8, 'indexes': [91]}]}
# {'word': 'excitedly', 'docs': [{'doc': 9, 'indexes': [127]}]}
# {'word': 'exhibitors', 'docs': [{'doc': 7, 'indexes': [69]}]}
# {'word': 'experimenting', 'docs': [{'doc': 4, 'indexes': [111]}]}
# {'word': 'explain', 'docs': [{'doc': 7, 'indexes': [29]}]}
# {'word': 'extra', 'docs': [{'doc': 2, 'indexes': [96]}, {'doc': 12, 'indexes': [60]}]}
# {'word': 'extra-large', 'docs': [{'doc': 6, 'indexes': [58]}]}
# {'word': 'eye', 'docs': [{'doc': 13, 'indexes': [42]}]}
# {'word': 'eyesight', 'docs': [{'doc': 13, 'indexes': [52]}]}
# {'word': 'facility', 'docs': [{'doc': 4, 'indexes': [96]}]}
# {'word': 'fact', 'docs': [{'doc': 13, 'indexes': [20]}]}
# {'word': 'failure', 'docs': [{'doc': 11, 'indexes': [153]}]}
# {'word': 'families', 'docs': [{'doc': 2, 'indexes': [60]}]}
# {'word': 'fantastic', 'docs': [{'doc': 7, 'indexes': [128]}]}
# {'word': 'fault', 'docs': [{'doc': 6, 'indexes': [86]}]}
# {'word': 'featured', 'docs': [{'doc': 7, 'indexes': [67]}]}
# {'word': 'federal', 'docs': [{'doc': 9, 'indexes': [161]}, {'doc': 12, 'indexes': [113, 135]}]}
# {'word': 'fee', 'docs': [{'doc': 2, 'indexes': [163]}, {'doc': 7, 'indexes': [100]}]}
# {'word': 'feel', 'docs': [{'doc': 5, 'indexes': [77, 123, 129]}]}
# {'word': 'feet', 'docs': [{'doc': 12, 'indexes': [5]}]}
# {'word': 'felix', 'docs': [{'doc': 4, 'indexes': [10]}]}
# {'word': 'female', 'docs': [{'doc': 4, 'indexes': [67]}, {'doc': 6, 'indexes': [23]}]}
# {'word': 'festival', 'docs': [{'doc': 7, 'indexes': [32, 50, 66, 101, 141, 168]}]}
# {'word': 'festivals', 'docs': [{'doc': 7, 'indexes': [151]}]}
# {'word': 'fiction', 'docs': [{'doc': 1, 'indexes': [72]}]}
# {'word': 'fight', 'docs': [{'doc': 8, 'indexes': [21, 26]}]}
# {'word': 'fill', 'docs': [{'doc': 3, 'indexes': [134]}]}
# {'word': 'filled.no', 'docs': [{'doc': 15, 'indexes': [129]}]}
# {'word': 'finally', 'docs': [{'doc': 1, 'indexes': [87]}]}
# {'word': 'find', 'docs': [{'doc': 11, 'indexes': [127]}]}
# {'word': 'fine', 'docs': [{'doc': 2, 'indexes': [135, 146]}]}
# {'word': 'fines', 'docs': [{'doc': 2, 'indexes': [170]}]}
# {'word': 'fire', 'docs': [{'doc': 11, 'indexes': [41]}, {'doc': 12, 'indexes': [16, 82, 91]}, {'doc': 15, 'indexes': [101]}]}
# {'word': 'first', 'docs': [{'doc': 4, 'indexes': [36]}, {'doc': 5, 'indexes': [44]}, {'doc': 9, 'indexes': [9, 29]}, {'doc': 12, 'indexes': [33]}, {'doc': 14, 'indexes': [34]}]}
# {'word': 'five', 'docs': [{'doc': 5, 'indexes': [53]}, {'doc': 10, 'indexes': [22]}, {'doc': 12, 'indexes': [25]}, {'doc': 14, 'indexes': [18]}]}
# {'word': 'five-year-old', 'docs': [{'doc': 15, 'indexes': [136]}]}
# {'word': 'fixing', 'docs': [{'doc': 13, 'indexes': [81]}]}
# {'word': 'flipped', 'docs': [{'doc': 9, 'indexes': [95]}]}
# {'word': 'following', 'docs': [{'doc': 1, 'indexes': [112]}, {'doc': 7, 'indexes': [77]}]}
# {'word': 'food', 'docs': [{'doc': 7, 'indexes': [84, 106]}, {'doc': 8, 'indexes': [20, 25, 69]}, {'doc': 13, 'indexes': [164]}]}
# {'word': 'foods', 'docs': [{'doc': 7, 'indexes': [90]}]}
# {'word': 'foot', 'docs': [{'doc': 13, 'indexes': [48]}]}
# {'word': 'foothill', 'docs': [{'doc': 10, 'indexes': [10]}]}
# {'word': 'forward', 'docs': [{'doc': 12, 'indexes': [45, 105]}]}
# {'word': 'found', 'docs': [{'doc': 15, 'indexes': [131, 138]}]}
# {'word': 'founders', 'docs': [{'doc': 7, 'indexes': [169]}]}
# {'word': 'four', 'docs': [{'doc': 1, 'indexes': [32]}, {'doc': 2, 'indexes': [59]}, {'doc': 12, 'indexes': [153]}, {'doc': 14, 'indexes': [67]}]}
# {'word': 'four-door', 'docs': [{'doc': 10, 'indexes': [30]}]}
# {'word': 'four-slice', 'docs': [{'doc': 10, 'indexes': [48]}]}
# {'word': 'francisco', 'docs': [{'doc': 7, 'indexes': [118]}]}
# {'word': 'free', 'docs': [{'doc': 6, 'indexes': [55]}, {'doc': 7, 'indexes': [102]}]}
# {'word': 'freeway', 'docs': [{'doc': 11, 'indexes': [11]}]}
# {'word': 'fresh', 'docs': [{'doc': 4, 'indexes': [46]}, {'doc': 6, 'indexes': [45]}, {'doc': 13, 'indexes': [93]}]}
# {'word': 'friction', 'docs': [{'doc': 2, 'indexes': [93]}]}
# {'word': 'friendly', 'docs': [{'doc': 13, 'indexes': [85, 105]}]}
# {'word': 'friends', 'docs': [{'doc': 5, 'indexes': [50, 64]}, {'doc': 13, 'indexes': [34]}, {'doc': 14, 'indexes': [52]}]}
# {'word': 'front', 'docs': [{'doc': 11, 'indexes': [20, 110]}]}
# {'word': 'fruit', 'docs': [{'doc': 13, 'indexes': [94]}]}
# {'word': 'full', 'docs': [{'doc': 11, 'indexes': [130]}, {'doc': 13, 'indexes': [106]}, {'doc': 15, 'indexes': [77]}]}
# {'word': 'funds', 'docs': [{'doc': 12, 'indexes': [114]}]}
# {'word': 'furniture', 'docs': [{'doc': 15, 'indexes': [59]}]}
# {'word': 'future', 'docs': [{'doc': 5, 'indexes': [155]}, {'doc': 12, 'indexes': [50]}]}
# {'word': 'gallon', 'docs': [{'doc': 3, 'indexes': [30, 121, 130]}, {'doc': 10, 'indexes': [64]}]}
# {'word': 'game', 'docs': [{'doc': 9, 'indexes': [25]}]}
# {'word': 'gangster', 'docs': [{'doc': 1, 'indexes': [20, 48]}]}
# {'word': 'gangsters', 'docs': [{'doc': 1, 'indexes': [93, 139]}]}
# {'word': 'garbage', 'docs': [{'doc': 15, 'indexes': [42, 46]}]}
# {'word': 'gas', 'docs': [{'doc': 3, 'indexes': [14, 25, 39, 44, 98, 119]}]}
# {'word': 'gasoline', 'docs': [{'doc': 3, 'indexes': [8]}]}
# {'word': 'gave', 'docs': [{'doc': 6, 'indexes': [53]}]}
# {'word': 'gear', 'docs': [{'doc': 15, 'indexes': [109]}]}
# {'word': 'generating', 'docs': [{'doc': 2, 'indexes': [55]}]}
# {'word': 'get', 'docs': [{'doc': 2, 'indexes': [159]}, {'doc': 3, 'indexes': [4, 126]}, {'doc': 5, 'indexes': [114]}, {'doc': 7, 'indexes': [135]}, {'doc': 12, 'indexes': [101]}, {'doc': 13, 'indexes': [109]}, {'doc': 14, 'indexes': [56]}]}
# {'word': 'gets', 'docs': [{'doc': 2, 'indexes': [19]}]}
# {'word': 'getting', 'docs': [{'doc': 9, 'indexes': [138]}]}
# {'word': 'geyser', 'docs': [{'doc': 11, 'indexes': [47]}]}
# {'word': 'gift', 'docs': [{'doc': 6, 'indexes': [56]}]}
# {'word': 'give', 'docs': [{'doc': 5, 'indexes': [101]}]}
# {'word': 'given', 'docs': [{'doc': 6, 'indexes': [44]}, {'doc': 7, 'indexes': [72]}]}
# {'word': 'gloves', 'docs': [{'doc': 15, 'indexes': [107]}]}
# {'word': 'go', 'docs': [{'doc': 1, 'indexes': [26]}, {'doc': 3, 'indexes': [106]}, {'doc': 5, 'indexes': [5, 8, 161, 179]}, {'doc': 6, 'indexes': [70, 82]}, {'doc': 13, 'indexes': [130]}, {'doc': 14, 'indexes': [126]}]}
# {'word': 'goal', 'docs': [{'doc': 4, 'indexes': [101]}]}
# {'word': 'goes', 'docs': [{'doc': 4, 'indexes': [70]}, {'doc': 5, 'indexes': [169]}, {'doc': 7, 'indexes': [11]}, {'doc': 14, 'indexes': [10]}]}
# {'word': 'going', 'docs': [{'doc': 9, 'indexes': [51]}, {'doc': 12, 'indexes': [22, 62, 158]}]}
# {'word': 'golf', 'docs': [{'doc': 15, 'indexes': [75, 79]}]}
# {'word': 'gone.', 'docs': [{'doc': 13, 'indexes': [55]}]}
# {'word': 'good', 'docs': [{'doc': 7, 'indexes': [136]}, {'doc': 12, 'indexes': [140]}]}
# {'word': 'got', 'docs': [{'doc': 9, 'indexes': [132]}, {'doc': 10, 'indexes': [36, 70]}, {'doc': 11, 'indexes': [35]}, {'doc': 12, 'indexes': [152]}, {'doc': 13, 'indexes': [127, 137]}]}
# {'word': 'government', 'docs': [{'doc': 5, 'indexes': [152]}, {'doc': 12, 'indexes': [156]}]}
# {'word': 'grabbed', 'docs': [{'doc': 8, 'indexes': [75]}]}
# {'word': 'grand', 'docs': [{'doc': 11, 'indexes': [63]}]}
# {'word': 'great', 'docs': [{'doc': 5, 'indexes': [137]}, {'doc': 7, 'indexes': [129]}, {'doc': 15, 'indexes': [133]}]}
# {'word': 'greater', 'docs': [{'doc': 9, 'indexes': [52]}]}
# {'word': 'grocery', 'docs': [{'doc': 3, 'indexes': [143]}]}
# {'word': 'groups—save', 'docs': [{'doc': 15, 'indexes': [93]}]}
# {'word': 'groups—the', 'docs': [{'doc': 15, 'indexes': [86]}]}
# {'word': 'grow', 'docs': [{'doc': 4, 'indexes': [45]}]}
# {'word': 'growing', 'docs': [{'doc': 4, 'indexes': [90]}]}
# {'word': 'guarantee', 'docs': [{'doc': 9, 'indexes': [57]}]}
# {'word': 'guards', 'docs': [{'doc': 8, 'indexes': [74, 77, 93]}]}
# {'word': 'guess', 'docs': [{'doc': 9, 'indexes': [30, 47]}]}
# {'word': 'guessed', 'docs': [{'doc': 9, 'indexes': [61]}]}
# {'word': 'guessing', 'docs': [{'doc': 9, 'indexes': [53]}]}
# {'word': 'guides', 'docs': [{'doc': 7, 'indexes': [21]}]}
# {'word': 'gun', 'docs': [{'doc': 1, 'indexes': [91, 99, 116, 127]}]}
# {'word': 'gunshots', 'docs': [{'doc': 13, 'indexes': [171]}]}
# {'word': 'guy', 'docs': [{'doc': 14, 'indexes': [75]}]}
# {'word': 'guy.jerry', 'docs': [{'doc': 1, 'indexes': [86]}]}
# {'word': 'half', 'docs': [{'doc': 4, 'indexes': [61]}, {'doc': 7, 'indexes': [43]}, {'doc': 8, 'indexes': [33]}, {'doc': 13, 'indexes': [176]}, {'doc': 15, 'indexes': [151, 156]}]}
# {'word': 'halloween', 'docs': [{'doc': 13, 'indexes': [89]}]}
# {'word': 'halt.turning', 'docs': [{'doc': 11, 'indexes': [85]}]}
# {'word': 'hamburgers', 'docs': [{'doc': 7, 'indexes': [92]}]}
# {'word': 'hamilton', 'docs': [{'doc': 12, 'indexes': [90]}]}
# {'word': 'handed', 'docs': [{'doc': 13, 'indexes': [90]}]}
# {'word': 'handle', 'docs': [{'doc': 4, 'indexes': [97]}]}
# {'word': 'happen', 'docs': [{'doc': 11, 'indexes': [39]}]}
# {'word': 'happened', 'docs': [{'doc': 13, 'indexes': [124]}]}
# {'word': 'happy', 'docs': [{'doc': 14, 'indexes': [85, 150]}]}
# {'word': 'hauled', 'docs': [{'doc': 8, 'indexes': [78]}, {'doc': 15, 'indexes': [117]}]}
# {'word': 'hawaiian', 'docs': [{'doc': 7, 'indexes': [93]}]}
# {'word': 'hazard', 'docs': [{'doc': 12, 'indexes': [17]}]}
# {'word': 'head', 'docs': [{'doc': 14, 'indexes': [152]}]}
# {'word': 'headaches', 'docs': [{'doc': 2, 'indexes': [197]}]}
# {'word': 'heads', 'docs': [{'doc': 9, 'indexes': [98]}]}
# {'word': 'heard', 'docs': [{'doc': 13, 'indexes': [169]}]}
# {'word': 'held', 'docs': [{'doc': 8, 'indexes': [5]}]}
# {'word': 'help', 'docs': [{'doc': 12, 'indexes': [47]}, {'doc': 13, 'indexes': [75]}]}
# {'word': 'herman', 'docs': [{'doc': 6, 'indexes': [14]}]}
# {'word': 'high', 'docs': [{'doc': 2, 'indexes': [15]}, {'doc': 5, 'indexes': [7]}, {'doc': 12, 'indexes': [124]}]}
# {'word': 'higher', 'docs': [{'doc': 3, 'indexes': [19]}, {'doc': 5, 'indexes': [178]}]}
# {'word': 'hill', 'docs': [{'doc': 9, 'indexes': [75]}]}
# {'word': 'hire', 'docs': [{'doc': 6, 'indexes': [68]}]}
# {'word': 'hit', 'docs': [{'doc': 9, 'indexes': [133]}]}
# {'word': 'hold', 'docs': [{'doc': 2, 'indexes': [121]}]}
# {'word': 'holiday', 'docs': [{'doc': 10, 'indexes': [44]}]}
# {'word': 'home', 'docs': [{'doc': 1, 'indexes': [45]}, {'doc': 10, 'indexes': [59, 76]}, {'doc': 14, 'indexes': [40, 42]}]}
# {'word': 'homebuyers', 'docs': [{'doc': 5, 'indexes': [0, 76]}]}
# {'word': 'homeowner', 'docs': [{'doc': 2, 'indexes': [141, 149, 165]}]}
# {'word': 'homeowners', 'docs': [{'doc': 2, 'indexes': [7, 36, 180]}]}
# {'word': 'homes', 'docs': [{'doc': 2, 'indexes': [9]}, {'doc': 12, 'indexes': [88]}]}
# {'word': 'hope', 'docs': [{'doc': 15, 'indexes': [38]}]}
# {'word': 'hopes', 'docs': [{'doc': 5, 'indexes': [112, 146]}]}
# {'word': 'horsetrail', 'docs': [{'doc': 3, 'indexes': [68]}]}
# {'word': 'hospital', 'docs': [{'doc': 9, 'indexes': [140, 142]}, {'doc': 11, 'indexes': [5]}]}
# {'word': 'hot', 'docs': [{'doc': 6, 'indexes': [33]}, {'doc': 10, 'indexes': [85]}]}
# {'word': 'hotel', 'docs': [{'doc': 11, 'indexes': [22]}]}
# {'word': 'hour', 'docs': [{'doc': 7, 'indexes': [44]}]}
# {'word': 'hourly', 'docs': [{'doc': 2, 'indexes': [104]}]}
# {'word': 'hours', 'docs': [{'doc': 9, 'indexes': [80]}, {'doc': 14, 'indexes': [49, 68, 78]}, {'doc': 15, 'indexes': [7]}]}
# {'word': 'house', 'docs': [{'doc': 2, 'indexes': [65]}, {'doc': 5, 'indexes': [38, 150, 187]}, {'doc': 13, 'indexes': [131]}]}
# {'word': 'housing', 'docs': [{'doc': 5, 'indexes': [3, 167, 173]}]}
# {'word': 'howard', 'docs': [{'doc': 14, 'indexes': [94, 142]}]}
# {'word': 'however', 'docs': [{'doc': 2, 'indexes': [42]}, {'doc': 11, 'indexes': [99]}]}
# {'word': 'huge', 'docs': [{'doc': 2, 'indexes': [71]}]}
# {'word': 'hurriedly', 'docs': [{'doc': 11, 'indexes': [59]}]}
# {'word': 'husband', 'docs': [{'doc': 7, 'indexes': [125]}]}
# {'word': 'hydrant', 'docs': [{'doc': 11, 'indexes': [42, 45]}]}
# {'word': 'ice', 'docs': [{'doc': 7, 'indexes': [95]}, {'doc': 15, 'indexes': [159]}]}
# {'word': 'idea', 'docs': [{'doc': 5, 'indexes': [154]}, {'doc': 7, 'indexes': [140]}]}
# {'word': 'ideas', 'docs': [{'doc': 12, 'indexes': [169]}]}
# {'word': 'immediately', 'docs': [{'doc': 13, 'indexes': [179]}]}
# {'word': 'implanted', 'docs': [{'doc': 4, 'indexes': [66]}]}
# {'word': 'inc.', 'docs': [{'doc': 4, 'indexes': [15, 43, 56, 83]}]}
# {'word': 'income', 'docs': [{'doc': 2, 'indexes': [21]}]}
# {'word': 'incomes', 'docs': [{'doc': 2, 'indexes': [16]}]}
# {'word': 'inconsiderate', 'docs': [{'doc': 2, 'indexes': [174]}, {'doc': 14, 'indexes': [28]}]}
# {'word': 'inevitably', 'docs': [{'doc': 5, 'indexes': [159]}]}
# {'word': 'inferno', 'docs': [{'doc': 12, 'indexes': [51]}]}
# {'word': 'influence', 'docs': [{'doc': 11, 'indexes': [158]}]}
# {'word': 'injured', 'docs': [{'doc': 6, 'indexes': [3]}]}
# {'word': 'inmates', 'docs': [{'doc': 8, 'indexes': [0, 11, 38]}]}
# {'word': 'insurance', 'docs': [{'doc': 9, 'indexes': [145]}]}
# {'word': 'interest', 'docs': [{'doc': 5, 'indexes': [16]}, {'doc': 13, 'indexes': [141]}]}
# {'word': 'invite', 'docs': [{'doc': 1, 'indexes': [81]}]}
# {'word': 'irritating', 'docs': [{'doc': 14, 'indexes': [140]}]}
# {'word': 'issued', 'docs': [{'doc': 15, 'indexes': [105]}]}
# {'word': 'item', 'docs': [{'doc': 8, 'indexes': [37, 54]}]}
# {'word': 'items', 'docs': [{'doc': 8, 'indexes': [46, 58]}]}
# {'word': 'jail', 'docs': [{'doc': 11, 'indexes': [7]}]}
# {'word': 'japanese–he', 'docs': [{'doc': 1, 'indexes': [59]}]}
# {'word': 'jerry', 'docs': [{'doc': 1, 'indexes': [0, 36, 44, 75, 131]}]}
# {'word': 'job', 'docs': [{'doc': 15, 'indexes': [19]}]}
# {'word': 'job-related', 'docs': [{'doc': 14, 'indexes': [72]}]}
# {'word': 'john', 'docs': [{'doc': 6, 'indexes': [51]}, {'doc': 10, 'indexes': [16, 79]}]}
# {'word': 'johnson', 'docs': [{'doc': 6, 'indexes': [52]}]}
# {'word': 'joke', 'docs': [{'doc': 7, 'indexes': [1]}]}
# {'word': 'joy', 'docs': [{'doc': 9, 'indexes': [116]}]}
# {'word': 'jumped', 'docs': [{'doc': 9, 'indexes': [115]}]}
# {'word': 'kick', 'docs': [{'doc': 5, 'indexes': [135]}]}
# {'word': 'kids', 'docs': [{'doc': 10, 'indexes': [80]}, {'doc': 13, 'indexes': [83, 87]}]}
# {'word': 'killing', 'docs': [{'doc': 3, 'indexes': [139]}]}
# {'word': 'kinds', 'docs': [{'doc': 7, 'indexes': [87]}, {'doc': 13, 'indexes': [120]}]}
# {'word': 'kitten', 'docs': [{'doc': 4, 'indexes': [72, 78, 85]}]}
# {'word': 'kittens', 'docs': [{'doc': 4, 'indexes': [104]}]}
# {'word': 'knee.jerry', 'docs': [{'doc': 1, 'indexes': [134]}]}
# {'word': 'knew', 'docs': [{'doc': 7, 'indexes': [146]}, {'doc': 14, 'indexes': [38]}]}
# {'word': 'know', 'docs': [{'doc': 2, 'indexes': [182]}, {'doc': 5, 'indexes': [172]}, {'doc': 12, 'indexes': [99, 161]}]}
# {'word': 'lake', 'docs': [{'doc': 9, 'indexes': [77]}]}
# {'word': 'landfill', 'docs': [{'doc': 15, 'indexes': [123]}]}
# {'word': 'landlord', 'docs': [{'doc': 14, 'indexes': [15]}]}
# {'word': 'lane', 'docs': [{'doc': 6, 'indexes': [10]}]}
# {'word': 'lap', 'docs': [{'doc': 6, 'indexes': [29]}]}
# {'word': 'last', 'docs': [{'doc': 5, 'indexes': [61]}, {'doc': 13, 'indexes': [5, 67, 172]}]}
# {'word': 'late', 'docs': [{'doc': 2, 'indexes': [86]}]}
# {'word': 'later', 'docs': [{'doc': 4, 'indexes': [76]}, {'doc': 5, 'indexes': [55]}, {'doc': 6, 'indexes': [71]}]}
# {'word': 'latest', 'docs': [{'doc': 14, 'indexes': [123]}]}
# {'word': 'lawn', 'docs': [{'doc': 2, 'indexes': [69]}]}
# {'word': 'leading', 'docs': [{'doc': 11, 'indexes': [8]}]}
# {'word': 'least', 'docs': [{'doc': 5, 'indexes': [80]}]}
# {'word': 'lee', 'docs': [{'doc': 4, 'indexes': [11, 94, 120]}]}
# {'word': 'left', 'docs': [{'doc': 9, 'indexes': [123]}, {'doc': 14, 'indexes': [41]}]}
# {'word': 'leftovers', 'docs': [{'doc': 14, 'indexes': [108]}]}
# {'word': 'legal', 'docs': [{'doc': 8, 'indexes': [44]}]}
# {'word': 'less', 'docs': [{'doc': 13, 'indexes': [125, 126]}]}
# {'word': 'let', 'docs': [{'doc': 6, 'indexes': [69]}]}
# {'word': 'letting', 'docs': [{'doc': 6, 'indexes': [81]}]}
# {'word': 'libraries', 'docs': [{'doc': 7, 'indexes': [23]}]}
# {'word': 'life', 'docs': [{'doc': 9, 'indexes': [8]}, {'doc': 13, 'indexes': [107]}, {'doc': 14, 'indexes': [91]}, {'doc': 15, 'indexes': [165]}]}
# {'word': 'light', 'docs': [{'doc': 13, 'indexes': [79]}, {'doc': 15, 'indexes': [8]}]}
# {'word': 'like', 'docs': [{'doc': 1, 'indexes': [90, 92, 138]}, {'doc': 5, 'indexes': [78, 124, 130]}, {'doc': 8, 'indexes': [59]}, {'doc': 13, 'indexes': [77]}, {'doc': 14, 'indexes': [1, 11]}]}
# {'word': 'liked', 'docs': [{'doc': 1, 'indexes': [69]}]}
# {'word': 'limp', 'docs': [{'doc': 1, 'indexes': [136]}]}
# {'word': 'line', 'docs': [{'doc': 3, 'indexes': [75, 101]}]}
# {'word': 'lined', 'docs': [{'doc': 15, 'indexes': [120]}]}
# {'word': 'lines', 'docs': [{'doc': 3, 'indexes': [53, 109]}]}
# {'word': 'lips', 'docs': [{'doc': 5, 'indexes': [13]}]}
# {'word': 'liquid', 'docs': [{'doc': 4, 'indexes': [52]}]}
# {'word': 'listen', 'docs': [{'doc': 2, 'indexes': [126]}, {'doc': 14, 'indexes': [57]}]}
# {'word': 'listening', 'docs': [{'doc': 13, 'indexes': [142]}]}
# {'word': 'little', 'docs': [{'doc': 5, 'indexes': [177]}, {'doc': 9, 'indexes': [134, 147]}, {'doc': 12, 'indexes': [172]}]}
# {'word': 'lived', 'docs': [{'doc': 1, 'indexes': [8]}, {'doc': 10, 'indexes': [7]}, {'doc': 13, 'indexes': [65]}]}
# {'word': 'lives', 'docs': [{'doc': 4, 'indexes': [27]}, {'doc': 8, 'indexes': [95]}]}
# {'word': 'living', 'docs': [{'doc': 12, 'indexes': [148]}]}
# {'word': 'loan', 'docs': [{'doc': 12, 'indexes': [159]}]}
# {'word': 'loans', 'docs': [{'doc': 12, 'indexes': [136]}]}
# {'word': 'local', 'docs': [{'doc': 5, 'indexes': [66]}, {'doc': 13, 'indexes': [166]}]}
# {'word': 'long', 'docs': [{'doc': 3, 'indexes': [61]}, {'doc': 5, 'indexes': [15, 182]}]}
# {'word': 'look', 'docs': [{'doc': 12, 'indexes': [44]}]}
# {'word': 'looking', 'docs': [{'doc': 5, 'indexes': [37]}, {'doc': 12, 'indexes': [104]}]}
# {'word': 'looking.', 'docs': [{'doc': 5, 'indexes': [108]}]}
# {'word': 'los', 'docs': [{'doc': 7, 'indexes': [3, 34, 157]}, {'doc': 11, 'indexes': [1, 18]}]}
# {'word': 'lose', 'docs': [{'doc': 5, 'indexes': [181]}, {'doc': 13, 'indexes': [140]}]}
# {'word': 'lot', 'docs': [{'doc': 2, 'indexes': [92]}, {'doc': 3, 'indexes': [43]}, {'doc': 13, 'indexes': [148]}]}
# {'word': 'lottery', 'docs': [{'doc': 9, 'indexes': [24, 124, 168]}]}
# {'word': 'loud', 'docs': [{'doc': 2, 'indexes': [87]}]}
# {'word': 'love', 'docs': [{'doc': 7, 'indexes': [122]}]}
# {'word': 'loved', 'docs': [{'doc': 1, 'indexes': [19, 60]}]}
# {'word': 'lowest', 'docs': [{'doc': 3, 'indexes': [24]}]}
# {'word': 'lozano', 'docs': [{'doc': 2, 'indexes': [2]}]}
# {'word': 'lucky', 'docs': [{'doc': 11, 'indexes': [107]}, {'doc': 12, 'indexes': [102]}, {'doc': 14, 'indexes': [74, 89]}]}
# ...
# {'word': 'steadily', 'docs': [{'doc': 13, 'indexes': [136]}]}
# {'word': 'steep', 'docs': [{'doc': 4, 'indexes': [31]}]}
# {'word': 'steering', 'docs': [{'doc': 11, 'indexes': [140]}]}
# {'word': 'still', 'docs': [{'doc': 2, 'indexes': [158]}, {'doc': 5, 'indexes': [122]}, {'doc': 9, 'indexes': [63, 159]}, {'doc': 10, 'indexes': [81]}]}
# {'word': 'stolen', 'docs': [{'doc': 11, 'indexes': [13]}]}
# {'word': 'stop', 'docs': [{'doc': 9, 'indexes': [34, 73, 104]}, {'doc': 11, 'indexes': [131]}]}
# {'word': 'stopped', 'docs': [{'doc': 2, 'indexes': [47]}, {'doc': 10, 'indexes': [61]}]}
# {'word': 'store', 'docs': [{'doc': 1, 'indexes': [43, 100]}, {'doc': 3, 'indexes': [144]}, {'doc': 10, 'indexes': [41]}]}
# {'word': 'stored', 'docs': [{'doc': 4, 'indexes': [51]}]}
# {'word': 'stray', 'docs': [{'doc': 4, 'indexes': [112]}]}
# {'word': 'streambed', 'docs': [{'doc': 15, 'indexes': [115]}]}
# {'word': 'street', 'docs': [{'doc': 9, 'indexes': [76, 131]}, {'doc': 10, 'indexes': [11]}, {'doc': 11, 'indexes': [72]}]}
# {'word': 'streets', 'docs': [{'doc': 2, 'indexes': [78]}]}
# {'word': 'stretch', 'docs': [{'doc': 15, 'indexes': [114]}]}
# {'word': 'studio', 'docs': [{'doc': 9, 'indexes': [125]}]}
# {'word': 'succeed', 'docs': [{'doc': 7, 'indexes': [148]}]}
# {'word': 'successfully', 'docs': [{'doc': 4, 'indexes': [122]}]}
# {'word': 'sudden', 'docs': [{'doc': 12, 'indexes': [95]}]}
# {'word': 'sue', 'docs': [{'doc': 6, 'indexes': [78]}]}
# {'word': 'sued', 'docs': [{'doc': 9, 'indexes': [152]}]}
# {'word': 'suffered', 'docs': [{'doc': 6, 'indexes': [17]}]}
# {'word': 'suggested', 'docs': [{'doc': 2, 'indexes': [132]}]}
# {'word': 'summer', 'docs': [{'doc': 2, 'indexes': [12, 35]}]}
# {'word': 'sunday', 'docs': [{'doc': 7, 'indexes': [65]}]}
# {'word': 'supposed', 'docs': [{'doc': 12, 'indexes': [166]}]}
# {'word': 'surcharge', 'docs': [{'doc': 2, 'indexes': [23]}]}
# {'word': 'sure', 'docs': [{'doc': 2, 'indexes': [153]}, {'doc': 12, 'indexes': [70]}]}
# {'word': 'surround', 'docs': [{'doc': 12, 'indexes': [41]}]}
# {'word': 'surrounded', 'docs': [{'doc': 12, 'indexes': [6]}]}
# {'word': 'survive', 'docs': [{'doc': 12, 'indexes': [49]}]}
# {'word': 'suv', 'docs': [{'doc': 11, 'indexes': [14, 104, 128]}]}
# {'word': 'table', 'docs': [{'doc': 5, 'indexes': [103]}]}
# {'word': 'take', 'docs': [{'doc': 15, 'indexes': [121]}]}
# {'word': 'taken', 'docs': [{'doc': 11, 'indexes': [4]}]}
# {'word': 'talk', 'docs': [{'doc': 7, 'indexes': [78]}, {'doc': 13, 'indexes': [119, 134]}]}
# {'word': 'talked', 'docs': [{'doc': 13, 'indexes': [156]}]}
# {'word': 'talking', 'docs': [{'doc': 9, 'indexes': [126]}, {'doc': 13, 'indexes': [143]}]}
# {'word': 'talks', 'docs': [{'doc': 7, 'indexes': [71]}]}
# {'word': 'tank', 'docs': [{'doc': 3, 'indexes': [135]}]}
# {'word': 'tax', 'docs': [{'doc': 10, 'indexes': [52]}]}
# {'word': 'taxes', 'docs': [{'doc': 9, 'indexes': [162]}]}
# {'word': 'teen', 'docs': [{'doc': 9, 'indexes': [109]}]}
# {'word': 'teenage', 'docs': [{'doc': 9, 'indexes': [84]}]}
# {'word': 'teenager', 'docs': [{'doc': 9, 'indexes': [101]}]}
# {'word': 'tell', 'docs': [{'doc': 1, 'indexes': [62]}, {'doc': 3, 'indexes': [73]}, {'doc': 13, 'indexes': [147]}]}
# {'word': 'telling', 'docs': [{'doc': 5, 'indexes': [23]}]}
# {'word': 'theater', 'docs': [{'doc': 1, 'indexes': [27]}]}
# {'word': 'thelma', 'docs': [{'doc': 12, 'indexes': [143]}]}
# {'word': 'them.some', 'docs': [{'doc': 2, 'indexes': [183]}]}
# {'word': 'thick', 'docs': [{'doc': 12, 'indexes': [7]}]}
# {'word': 'thing', 'docs': [{'doc': 9, 'indexes': [6, 10]}]}
# {'word': 'things', 'docs': [{'doc': 5, 'indexes': [160]}, {'doc': 11, 'indexes': [37]}, {'doc': 13, 'indexes': [76, 101, 121]}]}
# {'word': 'think', 'docs': [{'doc': 2, 'indexes': [185]}, {'doc': 12, 'indexes': [171]}]}
# {'word': 'thinks', 'docs': [{'doc': 2, 'indexes': [134]}]}
# {'word': 'though', 'docs': [{'doc': 3, 'indexes': [125]}]}
# {'word': 'thought', 'docs': [{'doc': 5, 'indexes': [51]}, {'doc': 15, 'indexes': [140]}]}
# {'word': 'thousands', 'docs': [{'doc': 12, 'indexes': [18]}]}
# {'word': 'three', 'docs': [{'doc': 1, 'indexes': [31]}, {'doc': 2, 'indexes': [57]}, {'doc': 10, 'indexes': [26]}, {'doc': 11, 'indexes': [67]}, {'doc': 15, 'indexes': [35]}]}
# {'word': 'three-bedroom', 'docs': [{'doc': 2, 'indexes': [64]}]}
# {'word': 'three-hour', 'docs': [{'doc': 9, 'indexes': [90]}]}
# {'word': 'threw', 'docs': [{'doc': 8, 'indexes': [68]}, {'doc': 11, 'indexes': [30]}]}
# {'word': 'tim', 'docs': [{'doc': 5, 'indexes': [36, 110]}]}
# {'word': 'time', 'docs': [{'doc': 1, 'indexes': [84]}, {'doc': 4, 'indexes': [59]}, {'doc': 13, 'indexes': [123]}, {'doc': 15, 'indexes': [34]}]}
# {'word': 'time.', 'docs': [{'doc': 15, 'indexes': [44]}]}
# {'word': 'times', 'docs': [{'doc': 1, 'indexes': [33]}, {'doc': 3, 'indexes': [64]}, {'doc': 9, 'indexes': [83, 108, 112, 118]}]}
# {'word': 'tired', 'docs': [{'doc': 5, 'indexes': [107]}, {'doc': 14, 'indexes': [4]}]}
# {'word': 'tires', 'docs': [{'doc': 15, 'indexes': [55]}]}
# {'word': 'toaster', 'docs': [{'doc': 10, 'indexes': [49]}]}
# {'word': 'today', 'docs': [{'doc': 3, 'indexes': [20, 136]}]}
# {'word': 'together', 'docs': [{'doc': 13, 'indexes': [190]}]}
# {'word': 'toilet', 'docs': [{'doc': 8, 'indexes': [62]}]}
# {'word': 'told', 'docs': [{'doc': 5, 'indexes': [95]}, {'doc': 14, 'indexes': [73]}]}
# {'word': 'tons', 'docs': [{'doc': 12, 'indexes': [20]}, {'doc': 13, 'indexes': [91]}, {'doc': 15, 'indexes': [16, 41]}]}
# {'word': 'too.', 'docs': [{'doc': 7, 'indexes': [138]}]}
# {'word': 'took', 'docs': [{'doc': 1, 'indexes': [17]}]}
# {'word': 'toppled', 'docs': [{'doc': 12, 'indexes': [35]}]}
# {'word': 'toss', 'docs': [{'doc': 2, 'indexes': [76]}]}
# {'word': 'totally', 'docs': [{'doc': 2, 'indexes': [168]}]}
# {'word': 'tough', 'docs': [{'doc': 9, 'indexes': [92]}]}
# {'word': 'toward', 'docs': [{'doc': 12, 'indexes': [93]}]}
# {'word': 'tower', 'docs': [{'doc': 8, 'indexes': [7, 79, 80]}]}
# {'word': 'town', 'docs': [{'doc': 12, 'indexes': [1, 42, 48]}]}
# {'word': 'toyola', 'docs': [{'doc': 10, 'indexes': [32]}]}
# {'word': 'trade', 'docs': [{'doc': 8, 'indexes': [39]}]}
# {'word': 'traffic', 'docs': [{'doc': 3, 'indexes': [67]}, {'doc': 7, 'indexes': [26]}, {'doc': 12, 'indexes': [64]}]}
# {'word': 'trash', 'docs': [{'doc': 2, 'indexes': [73, 77, 110]}, {'doc': 15, 'indexes': [122, 127]}]}
# {'word': 'tree', 'docs': [{'doc': 12, 'indexes': [129]}]}
# {'word': 'trees', 'docs': [{'doc': 12, 'indexes': [10, 19, 34, 116, 154]}]}
# {'word': 'tried', 'docs': [{'doc': 8, 'indexes': [18]}, {'doc': 11, 'indexes': [78]}]}
# {'word': 'triple-scoop', 'docs': [{'doc': 15, 'indexes': [158]}]}
# {'word': 'trucks', 'docs': [{'doc': 12, 'indexes': [61]}, {'doc': 15, 'indexes': [119]}]}
# {'word': 'try', 'docs': [{'doc': 12, 'indexes': [74]}]}
# {'word': 'trying', 'docs': [{'doc': 3, 'indexes': [3]}]}
# {'word': 'tune-ups', 'docs': [{'doc': 14, 'indexes': [119]}]}
# {'word': 'tuner', 'docs': [{'doc': 9, 'indexes': [3]}]}
# {'word': 'turned', 'docs': [{'doc': 11, 'indexes': [60]}]}
# {'word': 'tv', 'docs': [{'doc': 7, 'indexes': [8, 20]}, {'doc': 9, 'indexes': [88]}, {'doc': 15, 'indexes': [70]}]}
# {'word': 'twenty', 'docs': [{'doc': 5, 'indexes': [184]}]}
# {'word': 'twice', 'docs': [{'doc': 4, 'indexes': [13]}, {'doc': 12, 'indexes': [103]}, {'doc': 13, 'indexes': [116]}]}
# {'word': 'twin', 'docs': [{'doc': 4, 'indexes': [42, 55, 82]}]}
# {'word': 'two', 'docs': [{'doc': 2, 'indexes': [56]}, {'doc': 3, 'indexes': [45]}, {'doc': 6, 'indexes': [54]}, {'doc': 8, 'indexes': [2, 16, 76]}, {'doc': 9, 'indexes': [48, 65]}, {'doc': 10, 'indexes': [19]}, {'doc': 11, 'indexes': [73, 100, 124]}, {'doc': 12, 'indexes': [53]}, {'doc': 13, 'indexes': [170]}, {'doc': 14, 'indexes': [48, 77]}, {'doc': 15, 'indexes': [84, 91]}]}
# {'word': 'two-', 'docs': [{'doc': 2, 'indexes': [63]}]}
# {'word': 'two-bedroom', 'docs': [{'doc': 5, 'indexes': [46]}]}
# {'word': 'two-mile', 'docs': [{'doc': 15, 'indexes': [113]}]}
# {'word': 'underbrush', 'docs': [{'doc': 12, 'indexes': [8, 21]}]}
# {'word': 'unemployed', 'docs': [{'doc': 9, 'indexes': [1]}]}
# {'word': 'uneventful', 'docs': [{'doc': 11, 'indexes': [24]}]}
# {'word': 'unfortunately', 'docs': [{'doc': 12, 'indexes': [115]}]}
# {'word': 'unhappy', 'docs': [{'doc': 14, 'indexes': [82]}]}
# {'word': 'uninjured', 'docs': [{'doc': 11, 'indexes': [98]}]}
# {'word': 'unlucky', 'docs': [{'doc': 9, 'indexes': [172]}]}
# {'word': 'unpredictable', 'docs': [{'doc': 7, 'indexes': [164]}]}
# {'word': 'upset', 'docs': [{'doc': 6, 'indexes': [74]}]}
# {'word': 'us', 'docs': [{'doc': 7, 'indexes': [154]}]}
# {'word': 'use', 'docs': [{'doc': 15, 'indexes': [155]}]}
# {'word': 'used', 'docs': [{'doc': 1, 'indexes': [102]}, {'doc': 3, 'indexes': [5, 146]}, {'doc': 13, 'indexes': [74, 104, 113]}]}
# {'word': 'value', 'docs': [{'doc': 15, 'indexes': [134]}]}
# {'word': 'variable', 'docs': [{'doc': 9, 'indexes': [68, 81]}]}
# {'word': 'variables', 'docs': [{'doc': 9, 'indexes': [50, 66]}]}
# {'word': 'vehicle.when', 'docs': [{'doc': 11, 'indexes': [33]}]}
# {'word': 'vehicles', 'docs': [{'doc': 3, 'indexes': [60]}]}
# {'word': 'vendor', 'docs': [{'doc': 11, 'indexes': [52]}]}
# {'word': 'venice', 'docs': [{'doc': 5, 'indexes': [48, 90]}]}
# {'word': 'veterinarian', 'docs': [{'doc': 4, 'indexes': [37]}]}
# {'word': 'vicky', 'docs': [{'doc': 13, 'indexes': [98]}]}
# {'word': 'victoria', 'docs': [{'doc': 13, 'indexes': [15]}]}
# {'word': 'video', 'docs': [{'doc': 1, 'indexes': [35, 39, 42]}]}
# {'word': 'videos', 'docs': [{'doc': 1, 'indexes': [49]}, {'doc': 7, 'indexes': [10]}]}
# {'word': 'visiting', 'docs': [{'doc': 5, 'indexes': [63]}]}
# {'word': 'visitors', 'docs': [{'doc': 2, 'indexes': [188]}]}
# {'word': 'vittorio', 'docs': [{'doc': 13, 'indexes': [11, 36]}]}
# {'word': 'vittorios', 'docs': [{'doc': 13, 'indexes': [158]}]}
# {'word': 'volunteers', 'docs': [{'doc': 15, 'indexes': [4, 99]}]}
# {'word': 'wait', 'docs': [{'doc': 3, 'indexes': [83]}, {'doc': 4, 'indexes': [19]}, {'doc': 7, 'indexes': [42]}]}
# {'word': 'waited', 'docs': [{'doc': 3, 'indexes': [100]}]}
# {'word': 'waiting', 'docs': [{'doc': 6, 'indexes': [5]}]}
# {'word': 'walked', 'docs': [{'doc': 1, 'indexes': [14]}]}
# {'word': 'walks', 'docs': [{'doc': 1, 'indexes': [135]}]}
# {'word': 'want', 'docs': [{'doc': 5, 'indexes': [134]}]}
# {'word': 'warden', 'docs': [{'doc': 8, 'indexes': [96]}]}
# {'word': 'wash', 'docs': [{'doc': 6, 'indexes': [43]}]}
# {'word': 'washes', 'docs': [{'doc': 7, 'indexes': [28]}]}
# {'word': 'watch', 'docs': [{'doc': 1, 'indexes': [28, 83]}, {'doc': 15, 'indexes': [95, 153]}]}
# {'word': 'watches', 'docs': [{'doc': 7, 'indexes': [7]}]}
# {'word': 'watching', 'docs': [{'doc': 5, 'indexes': [2]}]}
# {'word': 'water', 'docs': [{'doc': 11, 'indexes': [43]}]}
# {'word': 'way', 'docs': [{'doc': 10, 'indexes': [58]}, {'doc': 12, 'indexes': [163]}]}
# {'word': 'weaned', 'docs': [{'doc': 4, 'indexes': [79]}]}
# {'word': 'wearing', 'docs': [{'doc': 11, 'indexes': [136]}]}
# {'word': 'website', 'docs': [{'doc': 2, 'indexes': [179]}]}
# {'word': 'week', 'docs': [{'doc': 2, 'indexes': [39, 125]}, {'doc': 8, 'indexes': [6, 14, 99]}, {'doc': 13, 'indexes': [117, 132]}]}
# {'word': 'weekend', 'docs': [{'doc': 7, 'indexes': [57]}, {'doc': 14, 'indexes': [129]}]}
# {'word': 'weekly', 'docs': [{'doc': 2, 'indexes': [10, 49]}]}
# {'word': 'weeks', 'docs': [{'doc': 4, 'indexes': [81]}]}
# {'word': 'well', 'docs': [{'doc': 1, 'indexes': [74]}, {'doc': 4, 'indexes': [71]}, {'doc': 12, 'indexes': [139]}, {'doc': 15, 'indexes': [20]}]}
# {'word': 'went', 'docs': [{'doc': 1, 'indexes': [34, 98, 115, 128, 130]}, {'doc': 8, 'indexes': [65]}, {'doc': 10, 'indexes': [4]}, {'doc': 11, 'indexes': [123]}]}
# {'word': 'west', 'docs': [{'doc': 7, 'indexes': [33]}, {'doc': 11, 'indexes': [61]}]}
# {'word': 'whales', 'docs': [{'doc': 15, 'indexes': [96, 154]}]}
# {'word': 'whatever', 'docs': [{'doc': 5, 'indexes': [97]}]}
# {'word': 'wheel', 'docs': [{'doc': 11, 'indexes': [141]}]}
# {'word': 'wheels', 'docs': [{'doc': 3, 'indexes': [151]}]}
# {'word': 'whether', 'docs': [{'doc': 2, 'indexes': [5]}, {'doc': 5, 'indexes': [117]}]}
# {'word': 'whiskey', 'docs': [{'doc': 11, 'indexes': [28]}]}
# {'word': 'white', 'docs': [{'doc': 1, 'indexes': [56]}]}
# {'word': 'whole', 'docs': [{'doc': 14, 'indexes': [58, 90]}]}
# {'word': 'whose', 'docs': [{'doc': 4, 'indexes': [25]}]}
# {'word': 'widow', 'docs': [{'doc': 12, 'indexes': [145]}]}
# {'word': 'widowed', 'docs': [{'doc': 13, 'indexes': [71]}]}
# {'word': 'wife', 'docs': [{'doc': 13, 'indexes': [14, 44]}]}
# {'word': 'win', 'docs': [{'doc': 9, 'indexes': [26, 58]}]}
# {'word': 'windows', 'docs': [{'doc': 8, 'indexes': [73]}]}
# {'word': 'winnings', 'docs': [{'doc': 9, 'indexes': [163]}]}
# {'word': 'woke', 'docs': [{'doc': 10, 'indexes': [83]}]}
# {'word': 'woman', 'docs': [{'doc': 13, 'indexes': [1, 12]}]}
# {'word': 'work', 'docs': [{'doc': 1, 'indexes': [15]}, {'doc': 2, 'indexes': [97, 137]}, {'doc': 3, 'indexes': [141]}, {'doc': 12, 'indexes': [46]}, {'doc': 15, 'indexes': [0, 82, 110]}]}
# {'word': 'worked', 'docs': [{'doc': 15, 'indexes': [5]}]}
# {'word': 'world', 'docs': [{'doc': 13, 'indexes': [193]}, {'doc': 14, 'indexes': [109]}]}
# {'word': 'worms', 'docs': [{'doc': 2, 'indexes': [45]}]}
# {'word': 'worth', 'docs': [{'doc': 2, 'indexes': [196]}, {'doc': 5, 'indexes': [189]}, {'doc': 9, 'indexes': [155]}, {'doc': 15, 'indexes': [142]}]}
# {'word': 'would', 'docs': [{'doc': 1, 'indexes': [25, 37, 76, 80, 89]}, {'doc': 2, 'indexes': [61, 66, 75, 80, 84, 157, 172, 181]}, {'doc': 6, 'indexes': [42, 76]}, {'doc': 7, 'indexes': [147, 156]}, {'doc': 8, 'indexes': [110]}, {'doc': 9, 'indexes': [71, 86]}, {'doc': 13, 'indexes': [118, 129, 133]}, {'doc': 14, 'indexes': [53, 149, 155]}, {'doc': 15, 'indexes': [147, 149]}]}
# {'word': 'wrong', 'docs': [{'doc': 5, 'indexes': [126]}, {'doc': 14, 'indexes': [158]}]}
# {'word': 'year', 'docs': [{'doc': 4, 'indexes': [100, 125]}, {'doc': 5, 'indexes': [62]}, {'doc': 7, 'indexes': [39, 40, 58, 121]}, {'doc': 13, 'indexes': [160]}, {'doc': 14, 'indexes': [14]}]}
# {'word': 'year.', 'docs': [{'doc': 4, 'indexes': [107]}]}
# {'word': 'years', 'docs': [{'doc': 1, 'indexes': [3, 97]}, {'doc': 2, 'indexes': [52]}, {'doc': 3, 'indexes': [46]}, {'doc': 5, 'indexes': [54, 185]}, {'doc': 7, 'indexes': [143]}, {'doc': 9, 'indexes': [16]}, {'doc': 10, 'indexes': [18, 23]}, {'doc': 12, 'indexes': [12, 26]}, {'doc': 13, 'indexes': [19, 69, 96]}, {'doc': 15, 'indexes': [36]}]}
# {'word': 'yelling', 'docs': [{'doc': 11, 'indexes': [144]}]}
# {'word': 'yellow', 'docs': [{'doc': 15, 'indexes': [126]}]}
# {'word': 'yet', 'docs': [{'doc': 14, 'indexes': [141, 153]}]}
# {'word': 'yield', 'docs': [{'doc': 11, 'indexes': [154]}]}
# {'word': 'young', 'docs': [{'doc': 3, 'indexes': [95]}, {'doc': 6, 'indexes': [22]}]}
# {'word': '’', 'docs': [{'doc': 1, 'indexes': [41, 132]}, {'doc': 2, 'indexes': [106, 114, 166, 176, 195]}, {'doc': 3, 'indexes': [81, 87, 90, 105, 116, 131, 137, 145, 152]}, {'doc': 4, 'indexes': [17]}, {'doc': 5, 'indexes': [12, 22, 32, 74, 94, 100, 104, 113, 132, 180]}, {'doc': 6, 'indexes': [62, 85]}, {'doc': 7, 'indexes': [59, 127]}, {'doc': 8, 'indexes': [94]}, {'doc': 9, 'indexes': [150, 165, 170]}, {'doc': 12, 'indexes': [73, 100, 147, 151, 157, 162]}, {'doc': 13, 'indexes': [64, 70, 102, 144, 154]}, {'doc': 14, 'indexes': [55, 88, 99, 105]}, {'doc': 15, 'indexes': [29, 39]}]}
# {'word': '“', 'docs': [{'doc': 1, 'indexes': [70]}, {'doc': 2, 'indexes': [25, 34]}, {'doc': 3, 'indexes': [72, 111]}, {'doc': 4, 'indexes': [6, 16, 89, 95]}, {'doc': 5, 'indexes': [6, 14, 31, 41, 93, 116, 157, 168]}, {'doc': 7, 'indexes': [36, 119, 126, 162]}, {'doc': 12, 'indexes': [52, 59, 138, 146]}, {'doc': 13, 'indexes': [56, 63, 112, 174, 182, 189]}, {'doc': 14, 'indexes': [23, 33, 87, 97]}, {'doc': 15, 'indexes': [18, 28]}]}
# {'word': '”', 'docs': [{'doc': 1, 'indexes': [73]}, {'doc': 2, 'indexes': [28, 41]}, {'doc': 3, 'indexes': [94, 153]}, {'doc': 4, 'indexes': [8, 29, 92, 108]}, {'doc': 5, 'indexes': [9, 24, 34, 72, 109, 139, 163, 191]}, {'doc': 7, 'indexes': [38, 123, 139, 165]}, {'doc': 12, 'indexes': [55, 80, 141, 174]}, {'doc': 13, 'indexes': [59, 150, 178, 187, 194]}, {'doc': 14, 'indexes': [31, 80, 92, 131]}, {'doc': 15, 'indexes': [22, 45]}]}

# %%
result=test_directory.find("People")
print(result)
for file in [directory_input[index-1] for index in result]:
    print(file)
# Out:
# [2, 3, 7, 12, 13, 14]
# docs/Rentals at the Oceanside Community.txt
# docs/Gasoline Prices Hit Record High.txt
# docs/A Festival of Books.txt
# docs/Trees Are a Threat.txt
# docs/A Murder-Suicide.txt
# docs/Happy and Unhappy Renters.txt

# %%
result=test_directory.find("Los")
print(result)
for file in [directory_input[index-1] for index in result]:
    print(file)
# Out:
# [7, 11]
# docs/A Festival of Books.txt
# docs/Freeway Chase Ends at Newsstand.txt

# %%
result = test_directory.find("People and Los")
print(result)
for file in [directory_input[index-1] for index in result]:
    print(file)
# Out:
# [7]
# docs/A Festival of Books.txt

# %%
result = test_directory.find("People OR Los")
print(result)
for file in [directory_input[index-1] for index in result]:
    print(file)
# Out:
# [2, 3, 7, 11, 12, 13, 14]
# docs/Rentals at the Oceanside Community.txt
# docs/Gasoline Prices Hit Record High.txt
# docs/A Festival of Books.txt
# docs/Freeway Chase Ends at Newsstand.txt
# docs/Trees Are a Threat.txt
# docs/A Murder-Suicide.txt
# docs/Happy and Unhappy Renters.txt

# %%
result = test_directory.find("piano near/4 said")
print(result)
for file in [directory_input[index-1] for index in result]:
    print(file)
# Out:
# [9]
# docs/Better To Be Unlucky.txt
